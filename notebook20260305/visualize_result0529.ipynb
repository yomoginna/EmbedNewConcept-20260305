# %% [markdown]
# # 最高到達accuracyを取得する

# %%
from datetime import date

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import os
import json
import re
import sys
from collections import defaultdict

project_root = os.path.join(os.getcwd(), "..")
result_dir = os.path.join(project_root, "results")


def load_file_and_extract_max_accs(date, lr, target_concept_config_name, model_size, result_dir):
    """各initVecTypeとseedに対して、回したepochs中の最高到達accuracyを抽出する関数"""
    # if target_concept_config_type != '':
    #     target_concept_config_type = '-' + target_concept_config_type
    # dirname_pattern1 = f"gemma-3-{model_size}B-lr0.01{target_concept_config_type}-{date}-hidden_layer(-?\\d+)-seed(\\d+)_target_concepts_initvecwith(.*)"
    # dirname_pattern2 = f"gemma-3-{model_size}B-lr0.01{target_concept_config_type}-{date}-seed(\\d+)_target_concepts_initvecwith(.*)"

    target_concept_config_name = target_concept_config_name.replace('.json', '')
    dirname_pattern1 = f"gemma-3-{model_size}B-lr{lr}-{date}-hidden_layer(-?\\d+)-seed(\\d+)_{target_concept_config_name}_initvecwith(.*)"
    dirname_pattern2 = f"gemma-3-{model_size}B-lr{lr}-{date}-seed(\\d+)_{target_concept_config_name}_initvecwith(.*)"
    initVecType_to_seed_to_maxacc = defaultdict(dict)
    initVecType_to_seed_to_epoch_at_maxacc = defaultdict(dict)
    for dirname in os.listdir(result_dir):

        if re.match(dirname_pattern1, dirname):
            match_groups = re.search(dirname_pattern1, dirname)
            layer_idx = int(match_groups.group(1))
            seed = int(match_groups.group(2))
            initVecType = f"{match_groups.group(3)}_layer{layer_idx}"
        elif re.match(dirname_pattern2, dirname):
            match_groups = re.search(dirname_pattern2, dirname)
            print(match_groups)
            seed = int(match_groups.group(1))
            initVecType = match_groups.group(2)
        else:
            if date in dirname:
                # print(dirname)
                pass
            continue  # ディレクトリ名がどちらのパターンにもマッチしない場合はスキップ

        # print(f"Processing directory: {dirname}, initVecType: {initVecType}, seed: {seed}")
        
        if not os.path.exists(os.path.join(result_dir, dirname, 'logit_score_summary.json')):
            # print(f"Warning: logit_score_summary.json not found in {dirname}. Skipping.")
            continue
        with open(os.path.join(result_dir, dirname, 'logit_score_summary.json'), "r") as f:
            concept_to_epoch_to_scores = json.load(f)

        # 各conceptについて、回したepochs中の最高到達accuracyとそのepochを抽出
        max_accs = []
        epochs_at_maxacc = []
        for epoch_to_scores in concept_to_epoch_to_scores.values():
            max_accuracy = 0
            max_epoch_at_maxacc = 0
            for epoch, scores in epoch_to_scores.items():
                # print(f"Epoch: {epoch}, Accuracy: {scores['accuracy']}")
                if scores['accuracy'] > max_accuracy:
                    max_accuracy = scores['accuracy']
                    max_epoch_at_maxacc = epoch
            max_accs.append(max_accuracy)
            epochs_at_maxacc.append(max_epoch_at_maxacc)
        # print(f"Max Accuracies: {max_accs}")
        # print(f"Epochs at Max Accuracies: {epochs_at_maxacc}")
        initVecType_to_seed_to_maxacc[initVecType][seed] = max_accs
        initVecType_to_seed_to_epoch_at_maxacc[initVecType][seed] = epochs_at_maxacc
    return initVecType_to_seed_to_maxacc, initVecType_to_seed_to_epoch_at_maxacc

# %% [markdown]
# ## 12B

# %%
date = '20260529'
model_size = '12'
lr = 0.003

target_concept_config_name = 'target_concepts_mini_13.json'

# %%
initVecType_to_seed_to_maxacc, initVecType_to_seed_to_epoch_at_maxacc = load_file_and_extract_max_accs(
    date, lr, target_concept_config_name, model_size, result_dir
)

seeds = set([seed for seed_to_maxacc in initVecType_to_seed_to_maxacc.values() for seed in seed_to_maxacc.keys()])
initVecType_lst = sorted(list(initVecType_to_seed_to_maxacc.keys()))

for seed in seeds:
    print(f"Seed: {seed}")
    for initVecType in initVecType_lst:
        max_accs = initVecType_to_seed_to_maxacc[initVecType].get(seed, None)
        if max_accs:
            mean_max_acc = np.mean(max_accs)
            std_max_acc = np.std(max_accs)
            print(f"\tInitVecType: {initVecType:15}, Seed: {seed}, Mean Max Accuracy: {mean_max_acc:.4f}, Std: {std_max_acc:.4f}")

print('\n' + '-' * 100 + '\n')

for seed in seeds:
    print(f"Seed: {seed}")
    for initVecType in initVecType_lst:
        epochs_at_maxacc = initVecType_to_seed_to_epoch_at_maxacc[initVecType].get(seed, None)

        if epochs_at_maxacc:
            mean_epoch_at_maxacc = np.mean([int(e) for e in epochs_at_maxacc])
            std_epoch_at_maxacc = np.std([int(e) for e in epochs_at_maxacc])
        print(f"\tInitVecType: {initVecType:15}, Seed: {seed}, Mean Epoch number at Max Accuracy: {mean_epoch_at_maxacc:.2f}, Std: {std_epoch_at_maxacc:.2f}")
# Out:
# <re.Match object; span=(0, 75), match='gemma-3-12B-lr0.003-20260529-seed13_target_concep>
# <re.Match object; span=(0, 85), match='gemma-3-12B-lr0.003-20260529-seed3_target_concept>
# <re.Match object; span=(0, 75), match='gemma-3-12B-lr0.003-20260529-seed18_target_concep>
# <re.Match object; span=(0, 85), match='gemma-3-12B-lr0.003-20260529-seed5_target_concept>
# <re.Match object; span=(0, 86), match='gemma-3-12B-lr0.003-20260529-seed13_target_concep>
# <re.Match object; span=(0, 74), match='gemma-3-12B-lr0.003-20260529-seed8_target_concept>
# <re.Match object; span=(0, 74), match='gemma-3-12B-lr0.003-20260529-seed2_target_concept>
# <re.Match object; span=(0, 85), match='gemma-3-12B-lr0.003-20260529-seed9_target_concept>
# <re.Match object; span=(0, 86), match='gemma-3-12B-lr0.003-20260529-seed11_target_concep>
# <re.Match object; span=(0, 74), match='gemma-3-12B-lr0.003-20260529-seed7_target_concept>
# <re.Match object; span=(0, 75), match='gemma-3-12B-lr0.003-20260529-seed14_target_concep>
# <re.Match object; span=(0, 86), match='gemma-3-12B-lr0.003-20260529-seed19_target_concep>
# <re.Match object; span=(0, 75), match='gemma-3-12B-lr0.003-20260529-seed12_target_concep>
# <re.Match object; span=(0, 85), match='gemma-3-12B-lr0.003-20260529-seed7_target_concept>
# <re.Match object; span=(0, 85), match='gemma-3-12B-lr0.003-20260529-seed4_target_concept>
# <re.Match object; span=(0, 86), match='gemma-3-12B-lr0.003-20260529-seed16_target_concep>
# <re.Match object; span=(0, 74), match='gemma-3-12B-lr0.003-20260529-seed1_target_concept>
# <re.Match object; span=(0, 85), match='gemma-3-12B-lr0.003-20260529-seed6_target_concept>
# <re.Match object; span=(0, 75), match='gemma-3-12B-lr0.003-20260529-seed11_target_concep>
# <re.Match object; span=(0, 74), match='gemma-3-12B-lr0.003-20260529-seed3_target_concept>
# <re.Match object; span=(0, 86), match='gemma-3-12B-lr0.003-20260529-seed14_target_concep>
# <re.Match object; span=(0, 86), match='gemma-3-12B-lr0.003-20260529-seed12_target_concep>
# <re.Match object; span=(0, 85), match='gemma-3-12B-lr0.003-20260529-seed2_target_concept>
# <re.Match object; span=(0, 74), match='gemma-3-12B-lr0.003-20260529-seed0_target_concept>
# <re.Match object; span=(0, 75), match='gemma-3-12B-lr0.003-20260529-seed17_target_concep>
# <re.Match object; span=(0, 75), match='gemma-3-12B-lr0.003-20260529-seed19_target_concep>
# <re.Match object; span=(0, 86), match='gemma-3-12B-lr0.003-20260529-seed18_target_concep>
# <re.Match object; span=(0, 74), match='gemma-3-12B-lr0.003-20260529-seed4_target_concept>
# <re.Match object; span=(0, 86), match='gemma-3-12B-lr0.003-20260529-seed17_target_concep>
# <re.Match object; span=(0, 74), match='gemma-3-12B-lr0.003-20260529-seed5_target_concept>
# <re.Match object; span=(0, 75), match='gemma-3-12B-lr0.003-20260529-seed15_target_concep>
# <re.Match object; span=(0, 86), match='gemma-3-12B-lr0.003-20260529-seed10_target_concep>
# <re.Match object; span=(0, 85), match='gemma-3-12B-lr0.003-20260529-seed0_target_concept>
# <re.Match object; span=(0, 75), match='gemma-3-12B-lr0.003-20260529-seed10_target_concep>
# <re.Match object; span=(0, 85), match='gemma-3-12B-lr0.003-20260529-seed1_target_concept>
# <re.Match object; span=(0, 74), match='gemma-3-12B-lr0.003-20260529-seed9_target_concept>
# <re.Match object; span=(0, 74), match='gemma-3-12B-lr0.003-20260529-seed6_target_concept>
# <re.Match object; span=(0, 85), match='gemma-3-12B-lr0.003-20260529-seed8_target_concept>
# <re.Match object; span=(0, 86), match='gemma-3-12B-lr0.003-20260529-seed15_target_concep>
# <re.Match object; span=(0, 75), match='gemma-3-12B-lr0.003-20260529-seed16_target_concep>
# Seed: 0
# 	InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 0, Mean Max Accuracy: 0.7415, Std: 0.1252
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 0, Mean Max Accuracy: 0.7895, Std: 0.1138
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 0, Mean Max Accuracy: 0.7829, Std: 0.1257
# 	InitVecType: norm_rand_vocab, Seed: 0, Mean Max Accuracy: 0.7508, Std: 0.1402
# 	InitVecType: zero           , Seed: 0, Mean Max Accuracy: 0.7261, Std: 0.1662
# Seed: 1
# 	InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 1, Mean Max Accuracy: 0.7923, Std: 0.1068
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 1, Mean Max Accuracy: 0.7610, Std: 0.1351
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 1, Mean Max Accuracy: 0.7500, Std: 0.1509
# 	InitVecType: norm_rand_vocab, Seed: 1, Mean Max Accuracy: 0.7685, Std: 0.1742
# 	InitVecType: zero           , Seed: 1, Mean Max Accuracy: 0.7355, Std: 0.1280
# Seed: 2
# 	InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 2, Mean Max Accuracy: 0.7656, Std: 0.1349
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 2, Mean Max Accuracy: 0.7698, Std: 0.1340
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 2, Mean Max Accuracy: 0.8006, Std: 0.1471
# 	InitVecType: norm_rand_vocab, Seed: 2, Mean Max Accuracy: 0.7251, Std: 0.1358
# 	InitVecType: zero           , Seed: 2, Mean Max Accuracy: 0.7611, Std: 0.1306
# Seed: 3
# 	InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 3, Mean Max Accuracy: 0.7786, Std: 0.1292
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 3, Mean Max Accuracy: 0.7642, Std: 0.1337
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 3, Mean Max Accuracy: 0.7704, Std: 0.1451
# 	InitVecType: norm_rand_vocab, Seed: 3, Mean Max Accuracy: 0.7019, Std: 0.1313
# 	InitVecType: zero           , Seed: 3, Mean Max Accuracy: 0.7134, Std: 0.1585
# Seed: 4
# 	InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 4, Mean Max Accuracy: 0.7851, Std: 0.1133
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 4, Mean Max Accuracy: 0.8070, Std: 0.1126
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 4, Mean Max Accuracy: 0.7188, Std: 0.1580
# 	InitVecType: norm_rand_vocab, Seed: 4, Mean Max Accuracy: 0.7440, Std: 0.1089
# 	InitVecType: zero           , Seed: 4, Mean Max Accuracy: 0.6756, Std: 0.1711
# Seed: 5
# 	InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 5, Mean Max Accuracy: 0.7785, Std: 0.1516
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 5, Mean Max Accuracy: 0.7605, Std: 0.1423
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 5, Mean Max Accuracy: 0.7900, Std: 0.1117
# 	InitVecType: norm_rand_vocab, Seed: 5, Mean Max Accuracy: 0.7638, Std: 0.1370
# 	InitVecType: zero           , Seed: 5, Mean Max Accuracy: 0.7219, Std: 0.1457
# Seed: 6
# 	InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 6, Mean Max Accuracy: 0.8140, Std: 0.1113
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 6, Mean Max Accuracy: 0.7661, Std: 0.1230
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 6, Mean Max Accuracy: 0.7944, Std: 0.1178
# 	InitVecType: norm_rand_vocab, Seed: 6, Mean Max Accuracy: 0.7634, Std: 0.1253
# 	InitVecType: zero           , Seed: 6, Mean Max Accuracy: 0.7201, Std: 0.1573
# Seed: 7
# 	InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 7, Mean Max Accuracy: 0.7800, Std: 0.1059
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 7, Mean Max Accuracy: 0.7971, Std: 0.1058
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 7, Mean Max Accuracy: 0.7790, Std: 0.1398
# 	InitVecType: norm_rand_vocab, Seed: 7, Mean Max Accuracy: 0.7758, Std: 0.1374
# 	InitVecType: zero           , Seed: 7, Mean Max Accuracy: 0.7654, Std: 0.1345
# Seed: 8
# 	InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 8, Mean Max Accuracy: 0.7667, Std: 0.1163
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 8, Mean Max Accuracy: 0.7497, Std: 0.1365
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 8, Mean Max Accuracy: 0.7367, Std: 0.1317
# 	InitVecType: norm_rand_vocab, Seed: 8, Mean Max Accuracy: 0.7369, Std: 0.1300
# 	InitVecType: zero           , Seed: 8, Mean Max Accuracy: 0.7362, Std: 0.1472
# Seed: 9
# 	InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 9, Mean Max Accuracy: 0.7928, Std: 0.1184
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 9, Mean Max Accuracy: 0.7451, Std: 0.1103
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 9, Mean Max Accuracy: 0.7769, Std: 0.1144
# 	InitVecType: norm_rand_vocab, Seed: 9, Mean Max Accuracy: 0.7333, Std: 0.1206
# 	InitVecType: zero           , Seed: 9, Mean Max Accuracy: 0.7042, Std: 0.1563
# Seed: 10
# 	InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 10, Mean Max Accuracy: 0.7626, Std: 0.1261
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 10, Mean Max Accuracy: 0.7363, Std: 0.1352
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 10, Mean Max Accuracy: 0.7852, Std: 0.1191
# 	InitVecType: norm_rand_vocab, Seed: 10, Mean Max Accuracy: 0.7309, Std: 0.1367
# 	InitVecType: zero           , Seed: 10, Mean Max Accuracy: 0.6921, Std: 0.1629
# Seed: 11
# 	InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 11, Mean Max Accuracy: 0.7884, Std: 0.1472
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 11, Mean Max Accuracy: 0.7616, Std: 0.1491
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 11, Mean Max Accuracy: 0.7558, Std: 0.1086
# 	InitVecType: norm_rand_vocab, Seed: 11, Mean Max Accuracy: 0.7406, Std: 0.1454
# 	InitVecType: zero           , Seed: 11, Mean Max Accuracy: 0.7442, Std: 0.1607
# Seed: 12
# 	InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 12, Mean Max Accuracy: 0.7780, Std: 0.1166
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 12, Mean Max Accuracy: 0.7757, Std: 0.1206
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 12, Mean Max Accuracy: 0.7609, Std: 0.1470
# 	InitVecType: norm_rand_vocab, Seed: 12, Mean Max Accuracy: 0.7797, Std: 0.1236
# 	InitVecType: zero           , Seed: 12, Mean Max Accuracy: 0.7098, Std: 0.1628
# Seed: 13
# 	InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 13, Mean Max Accuracy: 0.7645, Std: 0.1357
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 13, Mean Max Accuracy: 0.7846, Std: 0.1285
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 13, Mean Max Accuracy: 0.7609, Std: 0.1498
# 	InitVecType: norm_rand_vocab, Seed: 13, Mean Max Accuracy: 0.7374, Std: 0.1390
# 	InitVecType: zero           , Seed: 13, Mean Max Accuracy: 0.7145, Std: 0.1727
# Seed: 14
# 	InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 14, Mean Max Accuracy: 0.7845, Std: 0.1414
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 14, Mean Max Accuracy: 0.7885, Std: 0.1239
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 14, Mean Max Accuracy: 0.7927, Std: 0.0974
# 	InitVecType: norm_rand_vocab, Seed: 14, Mean Max Accuracy: 0.7937, Std: 0.1204
# 	InitVecType: zero           , Seed: 14, Mean Max Accuracy: 0.7206, Std: 0.1652
# Seed: 15
# 	InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 15, Mean Max Accuracy: 0.8021, Std: 0.0745
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 15, Mean Max Accuracy: 0.7869, Std: 0.1141
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 15, Mean Max Accuracy: 0.7961, Std: 0.1151
# 	InitVecType: norm_rand_vocab, Seed: 15, Mean Max Accuracy: 0.7538, Std: 0.1268
# 	InitVecType: zero           , Seed: 15, Mean Max Accuracy: 0.7379, Std: 0.1558
# Seed: 16
# 	InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 16, Mean Max Accuracy: 0.8322, Std: 0.0877
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 16, Mean Max Accuracy: 0.7628, Std: 0.1308
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 16, Mean Max Accuracy: 0.7244, Std: 0.1369
# 	InitVecType: norm_rand_vocab, Seed: 16, Mean Max Accuracy: 0.7279, Std: 0.1326
# 	InitVecType: zero           , Seed: 16, Mean Max Accuracy: 0.7823, Std: 0.1507
# Seed: 17
# 	InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 17, Mean Max Accuracy: 0.7794, Std: 0.1221
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 17, Mean Max Accuracy: 0.7600, Std: 0.1200
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 17, Mean Max Accuracy: 0.7771, Std: 0.1093
# 	InitVecType: norm_rand_vocab, Seed: 17, Mean Max Accuracy: 0.7377, Std: 0.1197
# 	InitVecType: zero           , Seed: 17, Mean Max Accuracy: 0.7152, Std: 0.1502
# Seed: 18
# 	InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 18, Mean Max Accuracy: 0.7784, Std: 0.1540
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 18, Mean Max Accuracy: 0.7961, Std: 0.0980
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 18, Mean Max Accuracy: 0.7926, Std: 0.1019
# 	InitVecType: norm_rand_vocab, Seed: 18, Mean Max Accuracy: 0.7489, Std: 0.1220
# 	InitVecType: zero           , Seed: 18, Mean Max Accuracy: 0.7179, Std: 0.1440
# Seed: 19
# 	InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 19, Mean Max Accuracy: 0.7816, Std: 0.0972
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 19, Mean Max Accuracy: 0.7624, Std: 0.1119
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 19, Mean Max Accuracy: 0.7704, Std: 0.1091
# 	InitVecType: norm_rand_vocab, Seed: 19, Mean Max Accuracy: 0.7490, Std: 0.1370
# 	InitVecType: zero           , Seed: 19, Mean Max Accuracy: 0.7098, Std: 0.1648
#
# ----------------------------------------------------------------------------------------------------
#
# Seed: 0
# 	InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 0, Mean Epoch number at Max Accuracy: 5.04, Std: 3.17
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 0, Mean Epoch number at Max Accuracy: 5.85, Std: 2.66
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 0, Mean Epoch number at Max Accuracy: 5.85, Std: 2.80
# 	InitVecType: norm_rand_vocab, Seed: 0, Mean Epoch number at Max Accuracy: 5.15, Std: 2.49
# 	InitVecType: zero           , Seed: 0, Mean Epoch number at Max Accuracy: 5.85, Std: 2.68
# Seed: 1
# 	InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 1, Mean Epoch number at Max Accuracy: 4.15, Std: 2.33
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 1, Mean Epoch number at Max Accuracy: 4.96, Std: 2.72
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 1, Mean Epoch number at Max Accuracy: 4.96, Std: 2.56
# 	InitVecType: norm_rand_vocab, Seed: 1, Mean Epoch number at Max Accuracy: 4.69, Std: 2.58
# 	InitVecType: zero           , Seed: 1, Mean Epoch number at Max Accuracy: 6.50, Std: 2.82
# Seed: 2
# 	InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 2, Mean Epoch number at Max Accuracy: 4.81, Std: 2.96
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 2, Mean Epoch number at Max Accuracy: 4.31, Std: 3.06
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 2, Mean Epoch number at Max Accuracy: 5.65, Std: 2.46
# 	InitVecType: norm_rand_vocab, Seed: 2, Mean Epoch number at Max Accuracy: 5.08, Std: 2.99
# 	InitVecType: zero           , Seed: 2, Mean Epoch number at Max Accuracy: 5.42, Std: 2.68
# Seed: 3
# 	InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 3, Mean Epoch number at Max Accuracy: 5.92, Std: 2.60
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 3, Mean Epoch number at Max Accuracy: 5.15, Std: 2.32
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 3, Mean Epoch number at Max Accuracy: 6.00, Std: 2.84
# 	InitVecType: norm_rand_vocab, Seed: 3, Mean Epoch number at Max Accuracy: 4.85, Std: 2.94
# 	InitVecType: zero           , Seed: 3, Mean Epoch number at Max Accuracy: 6.31, Std: 2.45
# Seed: 4
# 	InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 4, Mean Epoch number at Max Accuracy: 5.92, Std: 2.57
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 4, Mean Epoch number at Max Accuracy: 6.19, Std: 2.90
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 4, Mean Epoch number at Max Accuracy: 5.42, Std: 2.65
# 	InitVecType: norm_rand_vocab, Seed: 4, Mean Epoch number at Max Accuracy: 5.96, Std: 2.92
# 	InitVecType: zero           , Seed: 4, Mean Epoch number at Max Accuracy: 6.04, Std: 2.52
# Seed: 5
# 	InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 5, Mean Epoch number at Max Accuracy: 5.23, Std: 2.71
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 5, Mean Epoch number at Max Accuracy: 4.81, Std: 2.15
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 5, Mean Epoch number at Max Accuracy: 5.62, Std: 2.37
# 	InitVecType: norm_rand_vocab, Seed: 5, Mean Epoch number at Max Accuracy: 6.04, Std: 2.19
# 	InitVecType: zero           , Seed: 5, Mean Epoch number at Max Accuracy: 5.15, Std: 2.30
# Seed: 6
# 	InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 6, Mean Epoch number at Max Accuracy: 6.15, Std: 3.08
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 6, Mean Epoch number at Max Accuracy: 5.73, Std: 2.09
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 6, Mean Epoch number at Max Accuracy: 5.42, Std: 3.00
# 	InitVecType: norm_rand_vocab, Seed: 6, Mean Epoch number at Max Accuracy: 5.42, Std: 2.51
# 	InitVecType: zero           , Seed: 6, Mean Epoch number at Max Accuracy: 6.00, Std: 2.63
# Seed: 7
# 	InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 7, Mean Epoch number at Max Accuracy: 5.42, Std: 2.40
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 7, Mean Epoch number at Max Accuracy: 5.73, Std: 3.02
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 7, Mean Epoch number at Max Accuracy: 6.23, Std: 2.76
# 	InitVecType: norm_rand_vocab, Seed: 7, Mean Epoch number at Max Accuracy: 5.73, Std: 3.08
# 	InitVecType: zero           , Seed: 7, Mean Epoch number at Max Accuracy: 5.88, Std: 2.33
# Seed: 8
# 	InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 8, Mean Epoch number at Max Accuracy: 5.27, Std: 3.07
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 8, Mean Epoch number at Max Accuracy: 5.81, Std: 2.73
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 8, Mean Epoch number at Max Accuracy: 5.15, Std: 2.64
# 	InitVecType: norm_rand_vocab, Seed: 8, Mean Epoch number at Max Accuracy: 5.58, Std: 2.82
# 	InitVecType: zero           , Seed: 8, Mean Epoch number at Max Accuracy: 7.46, Std: 3.00
# Seed: 9
# 	InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 9, Mean Epoch number at Max Accuracy: 4.42, Std: 2.92
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 9, Mean Epoch number at Max Accuracy: 4.96, Std: 2.50
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 9, Mean Epoch number at Max Accuracy: 6.46, Std: 2.80
# 	InitVecType: norm_rand_vocab, Seed: 9, Mean Epoch number at Max Accuracy: 5.50, Std: 2.42
# 	InitVecType: zero           , Seed: 9, Mean Epoch number at Max Accuracy: 6.12, Std: 2.26
# Seed: 10
# 	InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 10, Mean Epoch number at Max Accuracy: 4.00, Std: 2.43
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 10, Mean Epoch number at Max Accuracy: 4.85, Std: 2.32
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 10, Mean Epoch number at Max Accuracy: 6.50, Std: 2.98
# 	InitVecType: norm_rand_vocab, Seed: 10, Mean Epoch number at Max Accuracy: 5.42, Std: 2.51
# 	InitVecType: zero           , Seed: 10, Mean Epoch number at Max Accuracy: 5.27, Std: 2.90
# Seed: 11
# 	InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 11, Mean Epoch number at Max Accuracy: 5.92, Std: 2.74
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 11, Mean Epoch number at Max Accuracy: 6.00, Std: 2.35
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 11, Mean Epoch number at Max Accuracy: 6.00, Std: 3.06
# 	InitVecType: norm_rand_vocab, Seed: 11, Mean Epoch number at Max Accuracy: 5.62, Std: 2.75
# 	InitVecType: zero           , Seed: 11, Mean Epoch number at Max Accuracy: 4.92, Std: 2.40
# Seed: 12
# 	InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 12, Mean Epoch number at Max Accuracy: 6.73, Std: 2.65
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 12, Mean Epoch number at Max Accuracy: 5.08, Std: 2.96
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 12, Mean Epoch number at Max Accuracy: 6.00, Std: 3.21
# 	InitVecType: norm_rand_vocab, Seed: 12, Mean Epoch number at Max Accuracy: 5.27, Std: 2.86
# 	InitVecType: zero           , Seed: 12, Mean Epoch number at Max Accuracy: 4.85, Std: 3.17
# Seed: 13
# 	InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 13, Mean Epoch number at Max Accuracy: 5.23, Std: 2.85
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 13, Mean Epoch number at Max Accuracy: 5.73, Std: 2.81
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 13, Mean Epoch number at Max Accuracy: 5.15, Std: 3.03
# 	InitVecType: norm_rand_vocab, Seed: 13, Mean Epoch number at Max Accuracy: 5.54, Std: 2.44
# 	InitVecType: zero           , Seed: 13, Mean Epoch number at Max Accuracy: 5.15, Std: 2.94
# Seed: 14
# 	InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 14, Mean Epoch number at Max Accuracy: 5.35, Std: 3.15
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 14, Mean Epoch number at Max Accuracy: 4.73, Std: 2.36
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 14, Mean Epoch number at Max Accuracy: 6.00, Std: 3.08
# 	InitVecType: norm_rand_vocab, Seed: 14, Mean Epoch number at Max Accuracy: 6.31, Std: 2.63
# 	InitVecType: zero           , Seed: 14, Mean Epoch number at Max Accuracy: 6.31, Std: 2.77
# Seed: 15
# 	InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 15, Mean Epoch number at Max Accuracy: 5.23, Std: 2.55
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 15, Mean Epoch number at Max Accuracy: 5.96, Std: 2.14
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 15, Mean Epoch number at Max Accuracy: 6.12, Std: 2.76
# 	InitVecType: norm_rand_vocab, Seed: 15, Mean Epoch number at Max Accuracy: 6.12, Std: 2.33
# 	InitVecType: zero           , Seed: 15, Mean Epoch number at Max Accuracy: 5.77, Std: 2.15
# Seed: 16
# 	InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 16, Mean Epoch number at Max Accuracy: 5.12, Std: 2.94
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 16, Mean Epoch number at Max Accuracy: 4.85, Std: 2.81
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 16, Mean Epoch number at Max Accuracy: 5.04, Std: 2.19
# 	InitVecType: norm_rand_vocab, Seed: 16, Mean Epoch number at Max Accuracy: 5.81, Std: 3.04
# 	InitVecType: zero           , Seed: 16, Mean Epoch number at Max Accuracy: 5.31, Std: 2.23
# Seed: 17
# 	InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 17, Mean Epoch number at Max Accuracy: 5.58, Std: 2.72
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 17, Mean Epoch number at Max Accuracy: 5.88, Std: 2.58
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 17, Mean Epoch number at Max Accuracy: 5.73, Std: 2.77
# 	InitVecType: norm_rand_vocab, Seed: 17, Mean Epoch number at Max Accuracy: 5.23, Std: 2.59
# 	InitVecType: zero           , Seed: 17, Mean Epoch number at Max Accuracy: 6.00, Std: 2.79
# Seed: 18
# 	InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 18, Mean Epoch number at Max Accuracy: 5.15, Std: 2.68
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 18, Mean Epoch number at Max Accuracy: 5.92, Std: 2.91
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 18, Mean Epoch number at Max Accuracy: 4.92, Std: 2.92
# 	InitVecType: norm_rand_vocab, Seed: 18, Mean Epoch number at Max Accuracy: 5.35, Std: 2.60
# 	InitVecType: zero           , Seed: 18, Mean Epoch number at Max Accuracy: 4.92, Std: 2.79
# Seed: 19
# 	InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 19, Mean Epoch number at Max Accuracy: 5.19, Std: 2.53
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 19, Mean Epoch number at Max Accuracy: 5.42, Std: 3.20
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 19, Mean Epoch number at Max Accuracy: 5.15, Std: 2.82
# 	InitVecType: norm_rand_vocab, Seed: 19, Mean Epoch number at Max Accuracy: 5.81, Std: 2.86
# 	InitVecType: zero           , Seed: 19, Mean Epoch number at Max Accuracy: 6.27, Std: 3.17

# %% [markdown]
# ## epoch4固定でaccuracyを計算する

# %%
sys.path.append(project_root)

from utils.gemma_train_and_test_utils import calculate_metrics

def get_concept_to_epoch_score(concept_result_dir, epoch):
    concept_to_results = {}
    for dirname in os.listdir(concept_result_dir):
        if dirname.endswith(".json"):
            continue
        concept = dirname

        # このconceptに対するepochの結果を読み込む
        logit_score_path = os.path.join(concept_result_dir, dirname, f"logit-scored_epoch{epoch}.json")
        
        if not os.path.exists(logit_score_path):
            # raise FileNotFoundError(f"Logit score file not found: {logit_score_path}")
            # print(f"Logit score file not found: {logit_score_path}. Skipping this concept.")
            continue
        
        try:
            with open(logit_score_path, 'r') as f:
                results = json.load(f)
        except Exception as e:
            raise(f"Error loading logit score file: {dirname}. Skipping this concept. Error: {e}")
            
        y_true_lst = [res['label'] for res in results]
        y_pred_lst = [res['pred'] for res in results]

        # score計算
        metrics = calculate_metrics(y_pred_lst, y_true_lst)

        concept_to_results[concept] = metrics

        # print(f"  Epoch {epoch}: Accuracy: {metrics['accuracy']:.4f}, Precision: {metrics['precision']:.4f}, Recall: {metrics['recall']:.4f}, F1: {metrics['F1']:.4f}")
    
    return concept_to_results





def load_file_and_calc_epoch_accs(date, epoch, lr, target_concept_config_name, model_size, result_dir, print_flag=False):
    """各initVecTypeとseedに対して、回したepochs中の最高到達accuracyを抽出する関数"""

    target_concept_config_name = target_concept_config_name.replace('.json', '')
    dirname_pattern1 = f"gemma-3-{model_size}B-lr{lr}-{date}-hidden_layer(-?\\d+)-seed(\\d+)_{target_concept_config_name}_initvecwith(.*)"
    dirname_pattern2 = f"gemma-3-{model_size}B-lr{lr}-{date}-seed(\\d+)_{target_concept_config_name}_initvecwith(.*)"

    initvectype_to_seed_to_acc = defaultdict(dict)
    for dirname in os.listdir(result_dir):
        p1_match = re.match(dirname_pattern1, dirname)
        p2_match = re.match(dirname_pattern2, dirname)

        if p1_match: #re.match(dirname_pattern1, dirname):
            match_groups = re.search(dirname_pattern1, dirname)
            layer_idx = int(match_groups.group(1))
            seed = int(match_groups.group(2))
            initVecType = f"{match_groups.group(3)}_layer{layer_idx}"
        elif p2_match: # re.match(dirname_pattern2, dirname):
            match_groups = re.search(dirname_pattern2, dirname)
            # print(match_groups)
            seed = int(match_groups.group(1))
            initVecType = match_groups.group(2)
        else:
            if date in dirname:
                pass
            continue  # ディレクトリ名がどちらのパターンにもマッチしない場合はスキップ

        concept_to_results = get_concept_to_epoch_score(os.path.join(result_dir, dirname), epoch)
        if len(concept_to_results) == 0:
            # print(f"No valid concepts with logit score files found for directory: {dirname}. Skipping.")
            continue
        sum_acc = 0
        for concept, score in concept_to_results.items():
            acc = score['accuracy']
            sum_acc += acc

        avg_acc = sum_acc / len(concept_to_results)
        initvectype_to_seed_to_acc[initVecType][seed] = avg_acc
        if print_flag:
            print(f"InitVecType: {initVecType}, Seed: {seed}, Average Accuracy at Epoch {epoch}: {avg_acc:.4f}")

    return initvectype_to_seed_to_acc

# %%
layer = 12
seed_num = 20
max_epoch = 10

cat_mean_accs, cat_std_accs = [], []
nearcat_mean_accs, nearcat_std_accs = [], []
farcat_mean_accs, farcat_std_accs = [], []
zero_mean_accs, zero_std_accs = [], []
norm_rand_vocab_mean_accs, norm_rand_vocab_std_accs = [], []

for epoch in range(0, max_epoch+1):
    print(f"Epoch: {epoch}")


    # date = '20260427'
    
    initvectype_to_seed_to_acc = load_file_and_calc_epoch_accs(date, epoch, lr=lr, 
                                                            target_concept_config_name=target_concept_config_name, 
                                                            model_size=model_size, 
                                                            result_dir=result_dir,
                                                            print_flag=False)

    # ** Cat **
    initVecType = f'CatCent_by_WikiSummaryRepeatHSMixed_layer{layer}'
    print(f"InitVecType: {initVecType}")
    acc_lst = []
    for seed in range(seed_num):
        seed_to_acc = initvectype_to_seed_to_acc.get(initVecType, {})
        acc = seed_to_acc.get(seed, None)
        if acc is not None:
            acc_lst.append(acc)
            print(f"InitVecType: {initVecType}, Seed: {seed}, Average Accuracy at Epoch {epoch}: {acc:.4f}")
        else:
            # print(f"\tInitVecType: {initVecType}, No data for Seed {seed}")
            pass
    print('\t', acc_lst)
        
    # mean ± std
    mean = np.mean(acc_lst)
    std = np.std(acc_lst)
    print(f"\taccuracy at epoch {epoch}: {mean:.4f} ± {std:.4f}")
    print()
    cat_acc_lst = acc_lst
    cat_mean_accs.append(mean)
    cat_std_accs.append(std)


    # ** nearCat ** [WIP] nearのみwikisummaryのrepeatを入れ忘れていたため現在再実験中。終わったらここもコメントアウトを外す -> 終わった
    initVecType = f'nearCatCent_by_WikiSummaryRepeatHSMixed_layer{layer}'
    print(f"InitVecType: {initVecType}")
    acc_lst = []
    for seed in range(seed_num): 
        seed_to_acc = initvectype_to_seed_to_acc.get(initVecType, {})
        acc = seed_to_acc.get(seed, None)
        if acc is not None:
            acc_lst.append(acc)
            print(f"\tInitVecType: {initVecType}, Seed: {seed}, Average Accuracy at Epoch {epoch}: {acc:.4f}")
        else:
            # print(f"\tInitVecType: {initVecType}, No data for Seed {seed}")
            pass
    print('\t', acc_lst)
        
    # mean ± std
    mean = np.mean(acc_lst)
    std = np.std(acc_lst)
    print(f"\taccuracy at epoch {epoch}: {mean:.4f} ± {std:.4f}")
    print()
    nearcat_acc_lst = acc_lst
    nearcat_mean_accs.append(mean)
    nearcat_std_accs.append(std)



    # ** farCat ** [WIP] 4/27より後の実験はother -> farとしているため適宜ここも修正する
    initVecType = f'farCatCent_by_WikiSummaryRepeatHSMixed_layer{layer}'
    print(f"InitVecType: {initVecType}")
    acc_lst = []
    for seed in range(seed_num):
        seed_to_acc = initvectype_to_seed_to_acc.get(initVecType, {})
        acc = seed_to_acc.get(seed, None)
        if acc is not None:
            acc_lst.append(acc)
            print(f"\tInitVecType: {initVecType}, Seed: {seed}, Average Accuracy at Epoch {epoch}: {acc:.4f}")
        else:
            # print(f"\tInitVecType: {initVecType}, No data for Seed {seed}")
            pass
    print('\t', acc_lst)
    
    # mean ± std
    mean = np.mean(acc_lst)
    std = np.std(acc_lst)
    print(f"\taccuracy at epoch {epoch}: {mean:.4f} ± {std:.4f}")
    print()
    farcat_acc_lst = acc_lst
    farcat_mean_accs.append(mean)
    farcat_std_accs.append(std)


    # ** norm_rand_vocab **
    initVecType = 'norm_rand_vocab'
    print(f"InitVecType: {initVecType}")
    acc_lst = []
    for seed in range(seed_num):
        seed_to_acc = initvectype_to_seed_to_acc.get(initVecType, {})
        acc = seed_to_acc.get(seed, None)
        if acc is not None:
            acc_lst.append(acc)
            print(f"\tInitVecType: {initVecType}, Seed: {seed}, Average Accuracy at Epoch {epoch}: {acc:.4f}")
        else:
            # print(f"\tInitVecType: {initVecType}, No data for Seed {seed}")
            pass
    print('\t', acc_lst)

    # mean ± std
    mean = np.mean(acc_lst)
    std = np.std(acc_lst)
    print(f"\taccuracy at epoch {epoch}: {mean:.4f} ± {std:.4f}")
    print()
    norm_rand_vocab_acc_lst = acc_lst
    norm_rand_vocab_mean_accs.append(mean)
    norm_rand_vocab_std_accs.append(std)



    # ** zero **
    initVecType = 'zero'
    print(f"InitVecType: {initVecType}")
    acc_lst = []
    for seed in range(seed_num):
        seed_to_acc = initvectype_to_seed_to_acc.get(initVecType, {})
        acc = seed_to_acc.get(seed, None)
        if acc is not None:
            acc_lst.append(acc)
            print(f"\tInitVecType: {initVecType}, Seed: {seed}, Average Accuracy at Epoch {epoch}: {acc:.4f}")
        else:
            # print(f"\tInitVecType: {initVecType}, No data for Seed {seed}")
            pass
    print('\t', acc_lst)

    # mean ± std
    mean = np.mean(acc_lst)
    std = np.std(acc_lst)
    print(f"\taccuracy at epoch {epoch}: {mean:.4f} ± {std:.4f}")
    zero_acc_lst = acc_lst
    zero_mean_accs.append(mean)
    zero_std_accs.append(std)

    print('\n==============================\n==============================\n')
    

# どの日付のモデルが読み込まれたのかの確認用
print(f"date: {date}")
# Out:
# Epoch: 0
# <re.Match object; span=(0, 75), match='gemma-3-12B-lr0.003-20260529-seed13_target_concep>
# <re.Match object; span=(0, 85), match='gemma-3-12B-lr0.003-20260529-seed3_target_concept>
# <re.Match object; span=(0, 75), match='gemma-3-12B-lr0.003-20260529-seed18_target_concep>
# <re.Match object; span=(0, 85), match='gemma-3-12B-lr0.003-20260529-seed5_target_concept>
# <re.Match object; span=(0, 86), match='gemma-3-12B-lr0.003-20260529-seed13_target_concep>
# <re.Match object; span=(0, 74), match='gemma-3-12B-lr0.003-20260529-seed8_target_concept>
# <re.Match object; span=(0, 74), match='gemma-3-12B-lr0.003-20260529-seed2_target_concept>
# <re.Match object; span=(0, 85), match='gemma-3-12B-lr0.003-20260529-seed9_target_concept>
# <re.Match object; span=(0, 86), match='gemma-3-12B-lr0.003-20260529-seed11_target_concep>
# <re.Match object; span=(0, 74), match='gemma-3-12B-lr0.003-20260529-seed7_target_concept>
# <re.Match object; span=(0, 75), match='gemma-3-12B-lr0.003-20260529-seed14_target_concep>
# <re.Match object; span=(0, 86), match='gemma-3-12B-lr0.003-20260529-seed19_target_concep>
# <re.Match object; span=(0, 75), match='gemma-3-12B-lr0.003-20260529-seed12_target_concep>
# <re.Match object; span=(0, 85), match='gemma-3-12B-lr0.003-20260529-seed7_target_concept>
# <re.Match object; span=(0, 85), match='gemma-3-12B-lr0.003-20260529-seed4_target_concept>
# <re.Match object; span=(0, 86), match='gemma-3-12B-lr0.003-20260529-seed16_target_concep>
# <re.Match object; span=(0, 74), match='gemma-3-12B-lr0.003-20260529-seed1_target_concept>
# <re.Match object; span=(0, 85), match='gemma-3-12B-lr0.003-20260529-seed6_target_concept>
# <re.Match object; span=(0, 75), match='gemma-3-12B-lr0.003-20260529-seed11_target_concep>
# <re.Match object; span=(0, 74), match='gemma-3-12B-lr0.003-20260529-seed3_target_concept>
# <re.Match object; span=(0, 86), match='gemma-3-12B-lr0.003-20260529-seed14_target_concep>
# <re.Match object; span=(0, 86), match='gemma-3-12B-lr0.003-20260529-seed12_target_concep>
# <re.Match object; span=(0, 85), match='gemma-3-12B-lr0.003-20260529-seed2_target_concept>
# <re.Match object; span=(0, 74), match='gemma-3-12B-lr0.003-20260529-seed0_target_concept>
# <re.Match object; span=(0, 75), match='gemma-3-12B-lr0.003-20260529-seed17_target_concep>
# <re.Match object; span=(0, 75), match='gemma-3-12B-lr0.003-20260529-seed19_target_concep>
# <re.Match object; span=(0, 86), match='gemma-3-12B-lr0.003-20260529-seed18_target_concep>
# <re.Match object; span=(0, 74), match='gemma-3-12B-lr0.003-20260529-seed4_target_concept>
# <re.Match object; span=(0, 86), match='gemma-3-12B-lr0.003-20260529-seed17_target_concep>
# <re.Match object; span=(0, 74), match='gemma-3-12B-lr0.003-20260529-seed5_target_concept>
# <re.Match object; span=(0, 75), match='gemma-3-12B-lr0.003-20260529-seed15_target_concep>
# <re.Match object; span=(0, 86), match='gemma-3-12B-lr0.003-20260529-seed10_target_concep>
# <re.Match object; span=(0, 85), match='gemma-3-12B-lr0.003-20260529-seed0_target_concept>
# <re.Match object; span=(0, 75), match='gemma-3-12B-lr0.003-20260529-seed10_target_concep>
# <re.Match object; span=(0, 85), match='gemma-3-12B-lr0.003-20260529-seed1_target_concept>
# <re.Match object; span=(0, 74), match='gemma-3-12B-lr0.003-20260529-seed9_target_concept>
# <re.Match object; span=(0, 74), match='gemma-3-12B-lr0.003-20260529-seed6_target_concept>
# <re.Match object; span=(0, 85), match='gemma-3-12B-lr0.003-20260529-seed8_target_concept>
# <re.Match object; span=(0, 86), match='gemma-3-12B-lr0.003-20260529-seed15_target_concep>
# <re.Match object; span=(0, 75), match='gemma-3-12B-lr0.003-20260529-seed16_target_concep>
# InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12
# InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 0, Average Accuracy at Epoch 0: 0.4035
# InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 1, Average Accuracy at Epoch 0: 0.4045
# InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 2, Average Accuracy at Epoch 0: 0.4012
# InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 3, Average Accuracy at Epoch 0: 0.4032
# InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 4, Average Accuracy at Epoch 0: 0.4023
# InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 5, Average Accuracy at Epoch 0: 0.4043
# InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 6, Average Accuracy at Epoch 0: 0.4027
# InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 7, Average Accuracy at Epoch 0: 0.4031
# InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 8, Average Accuracy at Epoch 0: 0.4021
# InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 9, Average Accuracy at Epoch 0: 0.4018
# InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 10, Average Accuracy at Epoch 0: 0.4021
# InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 11, Average Accuracy at Epoch 0: 0.4049
# InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 12, Average Accuracy at Epoch 0: 0.4010
# InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 13, Average Accuracy at Epoch 0: 0.4003
# InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 14, Average Accuracy at Epoch 0: 0.4037
# InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 15, Average Accuracy at Epoch 0: 0.3975
# InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 16, Average Accuracy at Epoch 0: 0.4006
# InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 17, Average Accuracy at Epoch 0: 0.4011
# InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 18, Average Accuracy at Epoch 0: 0.4008
# InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 19, Average Accuracy at Epoch 0: 0.4074
# 	 [0.40348249218601234, 0.404493059285288, 0.40119320299677674, 0.4032429414790388, 0.4022959421961636, 0.40431537647379034, 0.40266808708383994, 0.4031128278988025, 0.40211560250175743, 0.40176821491128345, 0.4021123486272951, 0.4049134565767742, 0.4010409623193421, 0.4002803385447865, 0.4036967414928658, 0.39747078855428924, 0.4006110547978793, 0.40108234333880055, 0.40080645354974087, 0.4073984593143712]
# 	accuracy at epoch 0: 0.4024 ± 0.0020
#
# InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 0, Average Accuracy at Epoch 0: 0.4024
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 1, Average Accuracy at Epoch 0: 0.4052
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 2, Average Accuracy at Epoch 0: 0.4045
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 3, Average Accuracy at Epoch 0: 0.4030
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 4, Average Accuracy at Epoch 0: 0.3983
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 5, Average Accuracy at Epoch 0: 0.3991
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 6, Average Accuracy at Epoch 0: 0.4053
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 7, Average Accuracy at Epoch 0: 0.4049
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 8, Average Accuracy at Epoch 0: 0.4084
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 9, Average Accuracy at Epoch 0: 0.4027
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 10, Average Accuracy at Epoch 0: 0.4066
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 11, Average Accuracy at Epoch 0: 0.4045
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 12, Average Accuracy at Epoch 0: 0.4042
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 13, Average Accuracy at Epoch 0: 0.4036
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 14, Average Accuracy at Epoch 0: 0.4021
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 15, Average Accuracy at Epoch 0: 0.4056
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 16, Average Accuracy at Epoch 0: 0.4022
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 17, Average Accuracy at Epoch 0: 0.4022
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 18, Average Accuracy at Epoch 0: 0.4045
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 19, Average Accuracy at Epoch 0: 0.4067
# 	 [0.4023691148008065, 0.40521446013597584, 0.40445554248946536, 0.40303221793474225, 0.3983214364743377, 0.3990681855858598, 0.40526609462615804, 0.4049463888674508, 0.40835180494095885, 0.402725521166522, 0.4065640211547756, 0.4044521737395374, 0.4042100628431359, 0.40357151032051697, 0.4021217975076859, 0.4056458316862092, 0.4022207819479149, 0.4021664798911244, 0.4044789616006658, 0.4067196613275612]
# 	accuracy at epoch 0: 0.4038 ± 0.0024
#
# InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 0, Average Accuracy at Epoch 0: 0.4084
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 1, Average Accuracy at Epoch 0: 0.4081
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 2, Average Accuracy at Epoch 0: 0.4077
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 3, Average Accuracy at Epoch 0: 0.4038
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 4, Average Accuracy at Epoch 0: 0.4109
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 5, Average Accuracy at Epoch 0: 0.4090
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 6, Average Accuracy at Epoch 0: 0.4069
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 7, Average Accuracy at Epoch 0: 0.4089
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 8, Average Accuracy at Epoch 0: 0.4097
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 9, Average Accuracy at Epoch 0: 0.4095
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 10, Average Accuracy at Epoch 0: 0.4096
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 11, Average Accuracy at Epoch 0: 0.4104
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 12, Average Accuracy at Epoch 0: 0.4075
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 13, Average Accuracy at Epoch 0: 0.4085
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 14, Average Accuracy at Epoch 0: 0.4036
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 15, Average Accuracy at Epoch 0: 0.4048
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 16, Average Accuracy at Epoch 0: 0.4090
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 17, Average Accuracy at Epoch 0: 0.4046
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 18, Average Accuracy at Epoch 0: 0.4107
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 19, Average Accuracy at Epoch 0: 0.4050
# 	 [0.4084080856379232, 0.4080785589407857, 0.40767725956208484, 0.4038182885763112, 0.41085722199846136, 0.40902250839445975, 0.4068835954160472, 0.40893168527374546, 0.40973757332477057, 0.4094850008692069, 0.4095961953291128, 0.41044961678168435, 0.40747749759728075, 0.4084960746868879, 0.40363407096874765, 0.4048392823333111, 0.40895373403888474, 0.4046153982089401, 0.41066486731875096, 0.40500234540181673]
# 	accuracy at epoch 0: 0.4078 ± 0.0022
#
# InitVecType: norm_rand_vocab
# 	InitVecType: norm_rand_vocab, Seed: 0, Average Accuracy at Epoch 0: 0.4023
# 	InitVecType: norm_rand_vocab, Seed: 1, Average Accuracy at Epoch 0: 0.4023
# 	InitVecType: norm_rand_vocab, Seed: 2, Average Accuracy at Epoch 0: 0.4023
# 	InitVecType: norm_rand_vocab, Seed: 3, Average Accuracy at Epoch 0: 0.4023
# 	InitVecType: norm_rand_vocab, Seed: 4, Average Accuracy at Epoch 0: 0.4023
# 	InitVecType: norm_rand_vocab, Seed: 5, Average Accuracy at Epoch 0: 0.4023
# 	InitVecType: norm_rand_vocab, Seed: 6, Average Accuracy at Epoch 0: 0.4023
# 	InitVecType: norm_rand_vocab, Seed: 7, Average Accuracy at Epoch 0: 0.4023
# 	InitVecType: norm_rand_vocab, Seed: 8, Average Accuracy at Epoch 0: 0.4023
# 	InitVecType: norm_rand_vocab, Seed: 9, Average Accuracy at Epoch 0: 0.4023
# 	InitVecType: norm_rand_vocab, Seed: 10, Average Accuracy at Epoch 0: 0.4023
# 	InitVecType: norm_rand_vocab, Seed: 11, Average Accuracy at Epoch 0: 0.4023
# 	InitVecType: norm_rand_vocab, Seed: 12, Average Accuracy at Epoch 0: 0.4023
# 	InitVecType: norm_rand_vocab, Seed: 13, Average Accuracy at Epoch 0: 0.4023
# 	InitVecType: norm_rand_vocab, Seed: 14, Average Accuracy at Epoch 0: 0.4023
# 	InitVecType: norm_rand_vocab, Seed: 15, Average Accuracy at Epoch 0: 0.4023
# 	InitVecType: norm_rand_vocab, Seed: 16, Average Accuracy at Epoch 0: 0.4023
# 	InitVecType: norm_rand_vocab, Seed: 17, Average Accuracy at Epoch 0: 0.4023
# 	InitVecType: norm_rand_vocab, Seed: 18, Average Accuracy at Epoch 0: 0.4023
# 	InitVecType: norm_rand_vocab, Seed: 19, Average Accuracy at Epoch 0: 0.4023
# 	 [0.40228898422638487, 0.40228898422638487, 0.40228898422638487, 0.40228898422638487, 0.40228898422638487, 0.40228898422638487, 0.40228898422638487, 0.40228898422638487, 0.40228898422638487, 0.40228898422638487, 0.40228898422638487, 0.40228898422638487, 0.40228898422638487, 0.40228898422638487, 0.40228898422638487, 0.40228898422638487, 0.40228898422638487, 0.40228898422638487, 0.40228898422638487, 0.40228898422638487]
# 	accuracy at epoch 0: 0.4023 ± 0.0000
#
# InitVecType: zero
# 	InitVecType: zero, Seed: 0, Average Accuracy at Epoch 0: 0.4080
# 	InitVecType: zero, Seed: 1, Average Accuracy at Epoch 0: 0.4080
# 	InitVecType: zero, Seed: 2, Average Accuracy at Epoch 0: 0.4080
# 	InitVecType: zero, Seed: 3, Average Accuracy at Epoch 0: 0.4080
# 	InitVecType: zero, Seed: 4, Average Accuracy at Epoch 0: 0.4080
# 	InitVecType: zero, Seed: 5, Average Accuracy at Epoch 0: 0.4080
# 	InitVecType: zero, Seed: 6, Average Accuracy at Epoch 0: 0.4080
# 	InitVecType: zero, Seed: 7, Average Accuracy at Epoch 0: 0.4080
# 	InitVecType: zero, Seed: 8, Average Accuracy at Epoch 0: 0.4080
# 	InitVecType: zero, Seed: 9, Average Accuracy at Epoch 0: 0.4080
# 	InitVecType: zero, Seed: 10, Average Accuracy at Epoch 0: 0.4080
# 	InitVecType: zero, Seed: 11, Average Accuracy at Epoch 0: 0.4080
# 	InitVecType: zero, Seed: 12, Average Accuracy at Epoch 0: 0.4080
# 	InitVecType: zero, Seed: 13, Average Accuracy at Epoch 0: 0.4080
# 	InitVecType: zero, Seed: 14, Average Accuracy at Epoch 0: 0.4080
# 	InitVecType: zero, Seed: 15, Average Accuracy at Epoch 0: 0.4080
# 	InitVecType: zero, Seed: 16, Average Accuracy at Epoch 0: 0.4080
# 	InitVecType: zero, Seed: 17, Average Accuracy at Epoch 0: 0.4080
# 	InitVecType: zero, Seed: 18, Average Accuracy at Epoch 0: 0.4080
# 	InitVecType: zero, Seed: 19, Average Accuracy at Epoch 0: 0.4080
# 	 [0.40800477739575464, 0.40800477739575464, 0.40800477739575464, 0.40800477739575464, 0.40800477739575464, 0.40800477739575464, 0.40800477739575464, 0.40800477739575464, 0.40800477739575464, 0.40800477739575464, 0.40800477739575464, 0.40800477739575464, 0.40800477739575464, 0.40800477739575464, 0.40800477739575464, 0.40800477739575464, 0.40800477739575464, 0.40800477739575464, 0.40800477739575464, 0.40800477739575464]
# 	accuracy at epoch 0: 0.4080 ± 0.0000
#
# ==============================
# ==============================
#
# Epoch: 1
# <re.Match object; span=(0, 75), match='gemma-3-12B-lr0.003-20260529-seed13_target_concep>
# <re.Match object; span=(0, 85), match='gemma-3-12B-lr0.003-20260529-seed3_target_concept>
# <re.Match object; span=(0, 75), match='gemma-3-12B-lr0.003-20260529-seed18_target_concep>
# <re.Match object; span=(0, 85), match='gemma-3-12B-lr0.003-20260529-seed5_target_concept>
# <re.Match object; span=(0, 86), match='gemma-3-12B-lr0.003-20260529-seed13_target_concep>
# <re.Match object; span=(0, 74), match='gemma-3-12B-lr0.003-20260529-seed8_target_concept>
# <re.Match object; span=(0, 74), match='gemma-3-12B-lr0.003-20260529-seed2_target_concept>
# <re.Match object; span=(0, 85), match='gemma-3-12B-lr0.003-20260529-seed9_target_concept>
# <re.Match object; span=(0, 86), match='gemma-3-12B-lr0.003-20260529-seed11_target_concep>
# <re.Match object; span=(0, 74), match='gemma-3-12B-lr0.003-20260529-seed7_target_concept>
# <re.Match object; span=(0, 75), match='gemma-3-12B-lr0.003-20260529-seed14_target_concep>
# <re.Match object; span=(0, 86), match='gemma-3-12B-lr0.003-20260529-seed19_target_concep>
# <re.Match object; span=(0, 75), match='gemma-3-12B-lr0.003-20260529-seed12_target_concep>
# <re.Match object; span=(0, 85), match='gemma-3-12B-lr0.003-20260529-seed7_target_concept>
# <re.Match object; span=(0, 85), match='gemma-3-12B-lr0.003-20260529-seed4_target_concept>
# <re.Match object; span=(0, 86), match='gemma-3-12B-lr0.003-20260529-seed16_target_concep>
# <re.Match object; span=(0, 74), match='gemma-3-12B-lr0.003-20260529-seed1_target_concept>
# <re.Match object; span=(0, 85), match='gemma-3-12B-lr0.003-20260529-seed6_target_concept>
# <re.Match object; span=(0, 75), match='gemma-3-12B-lr0.003-20260529-seed11_target_concep>
# <re.Match object; span=(0, 74), match='gemma-3-12B-lr0.003-20260529-seed3_target_concept>
# <re.Match object; span=(0, 86), match='gemma-3-12B-lr0.003-20260529-seed14_target_concep>
# <re.Match object; span=(0, 86), match='gemma-3-12B-lr0.003-20260529-seed12_target_concep>
# <re.Match object; span=(0, 85), match='gemma-3-12B-lr0.003-20260529-seed2_target_concept>
# <re.Match object; span=(0, 74), match='gemma-3-12B-lr0.003-20260529-seed0_target_concept>
# <re.Match object; span=(0, 75), match='gemma-3-12B-lr0.003-20260529-seed17_target_concep>
# <re.Match object; span=(0, 75), match='gemma-3-12B-lr0.003-20260529-seed19_target_concep>
# <re.Match object; span=(0, 86), match='gemma-3-12B-lr0.003-20260529-seed18_target_concep>
# <re.Match object; span=(0, 74), match='gemma-3-12B-lr0.003-20260529-seed4_target_concept>
# <re.Match object; span=(0, 86), match='gemma-3-12B-lr0.003-20260529-seed17_target_concep>
# <re.Match object; span=(0, 74), match='gemma-3-12B-lr0.003-20260529-seed5_target_concept>
# <re.Match object; span=(0, 75), match='gemma-3-12B-lr0.003-20260529-seed15_target_concep>
# <re.Match object; span=(0, 86), match='gemma-3-12B-lr0.003-20260529-seed10_target_concep>
# <re.Match object; span=(0, 85), match='gemma-3-12B-lr0.003-20260529-seed0_target_concept>
# <re.Match object; span=(0, 75), match='gemma-3-12B-lr0.003-20260529-seed10_target_concep>
# <re.Match object; span=(0, 85), match='gemma-3-12B-lr0.003-20260529-seed1_target_concept>
# <re.Match object; span=(0, 74), match='gemma-3-12B-lr0.003-20260529-seed9_target_concept>
# <re.Match object; span=(0, 74), match='gemma-3-12B-lr0.003-20260529-seed6_target_concept>
# <re.Match object; span=(0, 85), match='gemma-3-12B-lr0.003-20260529-seed8_target_concept>
# <re.Match object; span=(0, 86), match='gemma-3-12B-lr0.003-20260529-seed15_target_concep>
# <re.Match object; span=(0, 75), match='gemma-3-12B-lr0.003-20260529-seed16_target_concep>
# InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12
# InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 0, Average Accuracy at Epoch 1: 0.5541
# InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 1, Average Accuracy at Epoch 1: 0.6065
# InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 2, Average Accuracy at Epoch 1: 0.5701
# InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 3, Average Accuracy at Epoch 1: 0.5881
# InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 4, Average Accuracy at Epoch 1: 0.6059
# InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 5, Average Accuracy at Epoch 1: 0.5618
# InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 6, Average Accuracy at Epoch 1: 0.5992
# InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 7, Average Accuracy at Epoch 1: 0.5981
# InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 8, Average Accuracy at Epoch 1: 0.5578
# InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 9, Average Accuracy at Epoch 1: 0.5839
# InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 10, Average Accuracy at Epoch 1: 0.5581
# InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 11, Average Accuracy at Epoch 1: 0.5942
# InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 12, Average Accuracy at Epoch 1: 0.5444
# InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 13, Average Accuracy at Epoch 1: 0.5847
# InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 14, Average Accuracy at Epoch 1: 0.5957
# InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 15, Average Accuracy at Epoch 1: 0.6126
# InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 16, Average Accuracy at Epoch 1: 0.6108
# InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 17, Average Accuracy at Epoch 1: 0.5004
# InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 18, Average Accuracy at Epoch 1: 0.5677
# InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 19, Average Accuracy at Epoch 1: 0.5424
# 	 [0.5540758274737932, 0.6064654322160806, 0.5700890022176738, 0.5881198312373239, 0.6058971347226535, 0.5617735748582415, 0.5992485812617626, 0.5980686367459268, 0.5577816952064965, 0.5839067211780583, 0.5581468312210117, 0.5942450888010634, 0.5444067288688691, 0.5846578205118722, 0.5957173142258186, 0.6126214822100926, 0.6107698374071538, 0.5003987113974786, 0.5677101596912848, 0.542367424280047]
# 	accuracy at epoch 1: 0.5768 ± 0.0280
#
# InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 0, Average Accuracy at Epoch 1: 0.5960
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 1, Average Accuracy at Epoch 1: 0.5582
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 2, Average Accuracy at Epoch 1: 0.5851
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 3, Average Accuracy at Epoch 1: 0.5444
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 4, Average Accuracy at Epoch 1: 0.5270
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 5, Average Accuracy at Epoch 1: 0.5625
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 6, Average Accuracy at Epoch 1: 0.5829
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 7, Average Accuracy at Epoch 1: 0.5843
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 8, Average Accuracy at Epoch 1: 0.5676
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 9, Average Accuracy at Epoch 1: 0.5454
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 10, Average Accuracy at Epoch 1: 0.5851
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 11, Average Accuracy at Epoch 1: 0.5796
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 12, Average Accuracy at Epoch 1: 0.5808
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 13, Average Accuracy at Epoch 1: 0.5864
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 14, Average Accuracy at Epoch 1: 0.5737
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 15, Average Accuracy at Epoch 1: 0.6086
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 16, Average Accuracy at Epoch 1: 0.5049
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 17, Average Accuracy at Epoch 1: 0.5811
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 18, Average Accuracy at Epoch 1: 0.5643
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 19, Average Accuracy at Epoch 1: 0.5597
# 	 [0.5960377125873328, 0.5582210844302802, 0.5851339370552109, 0.5444272790748325, 0.5269921238913956, 0.5625078187559661, 0.5828548271994115, 0.5843006090275559, 0.5676447606174553, 0.5454247069764737, 0.5851265859566824, 0.5796043584349392, 0.5808010847597859, 0.5864494078294452, 0.5736706090299184, 0.6086293772483319, 0.5048716728299217, 0.5810907376884141, 0.5643146725873001, 0.5596609548144342]
# 	accuracy at epoch 1: 0.5689 ± 0.0237
#
# InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 0, Average Accuracy at Epoch 1: 0.5735
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 1, Average Accuracy at Epoch 1: 0.5593
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 2, Average Accuracy at Epoch 1: 0.6007
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 3, Average Accuracy at Epoch 1: 0.5615
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 4, Average Accuracy at Epoch 1: 0.6038
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 5, Average Accuracy at Epoch 1: 0.5699
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 6, Average Accuracy at Epoch 1: 0.5540
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 7, Average Accuracy at Epoch 1: 0.5787
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 8, Average Accuracy at Epoch 1: 0.6001
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 9, Average Accuracy at Epoch 1: 0.5512
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 10, Average Accuracy at Epoch 1: 0.5459
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 11, Average Accuracy at Epoch 1: 0.5543
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 12, Average Accuracy at Epoch 1: 0.5720
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 13, Average Accuracy at Epoch 1: 0.5500
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 14, Average Accuracy at Epoch 1: 0.5756
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 15, Average Accuracy at Epoch 1: 0.5687
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 16, Average Accuracy at Epoch 1: 0.5261
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 17, Average Accuracy at Epoch 1: 0.5603
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 18, Average Accuracy at Epoch 1: 0.5871
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 19, Average Accuracy at Epoch 1: 0.5703
# 	 [0.5734627865997043, 0.5592837705470484, 0.6006955501622145, 0.561479904534351, 0.6037891124019686, 0.5698898821159832, 0.5539701231604643, 0.5787214240334273, 0.6001348418295134, 0.5511969962284561, 0.5458577822639168, 0.5543162881574519, 0.5720310661209083, 0.5500303189692458, 0.5755980391468378, 0.5687023948496253, 0.5260835224144972, 0.5602556729502147, 0.5870675888585718, 0.5702949992912697]
# 	accuracy at epoch 1: 0.5681 ± 0.0192
#
# InitVecType: norm_rand_vocab
# 	InitVecType: norm_rand_vocab, Seed: 0, Average Accuracy at Epoch 1: 0.5442
# 	InitVecType: norm_rand_vocab, Seed: 1, Average Accuracy at Epoch 1: 0.5781
# 	InitVecType: norm_rand_vocab, Seed: 2, Average Accuracy at Epoch 1: 0.5126
# 	InitVecType: norm_rand_vocab, Seed: 3, Average Accuracy at Epoch 1: 0.5147
# 	InitVecType: norm_rand_vocab, Seed: 4, Average Accuracy at Epoch 1: 0.5307
# 	InitVecType: norm_rand_vocab, Seed: 5, Average Accuracy at Epoch 1: 0.5707
# 	InitVecType: norm_rand_vocab, Seed: 6, Average Accuracy at Epoch 1: 0.5178
# 	InitVecType: norm_rand_vocab, Seed: 7, Average Accuracy at Epoch 1: 0.5589
# 	InitVecType: norm_rand_vocab, Seed: 8, Average Accuracy at Epoch 1: 0.5538
# 	InitVecType: norm_rand_vocab, Seed: 9, Average Accuracy at Epoch 1: 0.4950
# 	InitVecType: norm_rand_vocab, Seed: 10, Average Accuracy at Epoch 1: 0.5105
# 	InitVecType: norm_rand_vocab, Seed: 11, Average Accuracy at Epoch 1: 0.5451
# 	InitVecType: norm_rand_vocab, Seed: 12, Average Accuracy at Epoch 1: 0.5761
# 	InitVecType: norm_rand_vocab, Seed: 13, Average Accuracy at Epoch 1: 0.5182
# 	InitVecType: norm_rand_vocab, Seed: 14, Average Accuracy at Epoch 1: 0.5449
# 	InitVecType: norm_rand_vocab, Seed: 15, Average Accuracy at Epoch 1: 0.5261
# 	InitVecType: norm_rand_vocab, Seed: 16, Average Accuracy at Epoch 1: 0.5631
# 	InitVecType: norm_rand_vocab, Seed: 17, Average Accuracy at Epoch 1: 0.4969
# 	InitVecType: norm_rand_vocab, Seed: 18, Average Accuracy at Epoch 1: 0.5023
# 	InitVecType: norm_rand_vocab, Seed: 19, Average Accuracy at Epoch 1: 0.5430
# 	 [0.5442155264942352, 0.5781049577401427, 0.5125766754387141, 0.5147227990280107, 0.5307256512416604, 0.5707008800684792, 0.5178250928497434, 0.558903842440574, 0.5538149991545629, 0.49503376630358714, 0.5105192354577148, 0.5450780671482887, 0.5760933974886131, 0.5182339032122587, 0.544866851423788, 0.5261312012159951, 0.56314226990128, 0.49694493546763435, 0.5022964164414796, 0.542958185914428]
# 	accuracy at epoch 1: 0.5351 ± 0.0257
#
# InitVecType: zero
# 	InitVecType: zero, Seed: 0, Average Accuracy at Epoch 1: 0.4821
# 	InitVecType: zero, Seed: 1, Average Accuracy at Epoch 1: 0.5305
# 	InitVecType: zero, Seed: 2, Average Accuracy at Epoch 1: 0.5045
# 	InitVecType: zero, Seed: 3, Average Accuracy at Epoch 1: 0.4525
# 	InitVecType: zero, Seed: 4, Average Accuracy at Epoch 1: 0.4697
# 	InitVecType: zero, Seed: 5, Average Accuracy at Epoch 1: 0.5133
# 	InitVecType: zero, Seed: 6, Average Accuracy at Epoch 1: 0.5278
# 	InitVecType: zero, Seed: 7, Average Accuracy at Epoch 1: 0.5088
# 	InitVecType: zero, Seed: 8, Average Accuracy at Epoch 1: 0.4645
# 	InitVecType: zero, Seed: 9, Average Accuracy at Epoch 1: 0.4651
# 	InitVecType: zero, Seed: 10, Average Accuracy at Epoch 1: 0.4831
# 	InitVecType: zero, Seed: 11, Average Accuracy at Epoch 1: 0.5149
# 	InitVecType: zero, Seed: 12, Average Accuracy at Epoch 1: 0.4994
# 	InitVecType: zero, Seed: 13, Average Accuracy at Epoch 1: 0.4685
# 	InitVecType: zero, Seed: 14, Average Accuracy at Epoch 1: 0.4849
# 	InitVecType: zero, Seed: 15, Average Accuracy at Epoch 1: 0.5223
# 	InitVecType: zero, Seed: 16, Average Accuracy at Epoch 1: 0.5360
# 	InitVecType: zero, Seed: 17, Average Accuracy at Epoch 1: 0.5090
# 	InitVecType: zero, Seed: 18, Average Accuracy at Epoch 1: 0.4820
# 	InitVecType: zero, Seed: 19, Average Accuracy at Epoch 1: 0.4642
# 	 [0.4821130442354127, 0.5304823902300224, 0.504469585892832, 0.4525235966596088, 0.4696716699588534, 0.5133343302302849, 0.5278065079304034, 0.508828074138143, 0.4645248827451375, 0.46507000274518767, 0.48308134338673053, 0.514891123372569, 0.4993665890212879, 0.4685294308919803, 0.48487376151624006, 0.5223366522627704, 0.5359796858071223, 0.5090070292111442, 0.482025306239911, 0.4642334222845506]
# 	accuracy at epoch 1: 0.4942 ± 0.0250
#
# ==============================
# ==============================
#
# Epoch: 2
# <re.Match object; span=(0, 75), match='gemma-3-12B-lr0.003-20260529-seed13_target_concep>
# <re.Match object; span=(0, 85), match='gemma-3-12B-lr0.003-20260529-seed3_target_concept>
# <re.Match object; span=(0, 75), match='gemma-3-12B-lr0.003-20260529-seed18_target_concep>
# <re.Match object; span=(0, 85), match='gemma-3-12B-lr0.003-20260529-seed5_target_concept>
# <re.Match object; span=(0, 86), match='gemma-3-12B-lr0.003-20260529-seed13_target_concep>
# <re.Match object; span=(0, 74), match='gemma-3-12B-lr0.003-20260529-seed8_target_concept>
# <re.Match object; span=(0, 74), match='gemma-3-12B-lr0.003-20260529-seed2_target_concept>
# <re.Match object; span=(0, 85), match='gemma-3-12B-lr0.003-20260529-seed9_target_concept>
# <re.Match object; span=(0, 86), match='gemma-3-12B-lr0.003-20260529-seed11_target_concep>
# <re.Match object; span=(0, 74), match='gemma-3-12B-lr0.003-20260529-seed7_target_concept>
# <re.Match object; span=(0, 75), match='gemma-3-12B-lr0.003-20260529-seed14_target_concep>
# <re.Match object; span=(0, 86), match='gemma-3-12B-lr0.003-20260529-seed19_target_concep>
# <re.Match object; span=(0, 75), match='gemma-3-12B-lr0.003-20260529-seed12_target_concep>
# <re.Match object; span=(0, 85), match='gemma-3-12B-lr0.003-20260529-seed7_target_concept>
# <re.Match object; span=(0, 85), match='gemma-3-12B-lr0.003-20260529-seed4_target_concept>
# <re.Match object; span=(0, 86), match='gemma-3-12B-lr0.003-20260529-seed16_target_concep>
# <re.Match object; span=(0, 74), match='gemma-3-12B-lr0.003-20260529-seed1_target_concept>
# <re.Match object; span=(0, 85), match='gemma-3-12B-lr0.003-20260529-seed6_target_concept>
# <re.Match object; span=(0, 75), match='gemma-3-12B-lr0.003-20260529-seed11_target_concep>
# <re.Match object; span=(0, 74), match='gemma-3-12B-lr0.003-20260529-seed3_target_concept>
# <re.Match object; span=(0, 86), match='gemma-3-12B-lr0.003-20260529-seed14_target_concep>
# <re.Match object; span=(0, 86), match='gemma-3-12B-lr0.003-20260529-seed12_target_concep>
# <re.Match object; span=(0, 85), match='gemma-3-12B-lr0.003-20260529-seed2_target_concept>
# <re.Match object; span=(0, 74), match='gemma-3-12B-lr0.003-20260529-seed0_target_concept>
# <re.Match object; span=(0, 75), match='gemma-3-12B-lr0.003-20260529-seed17_target_concep>
# <re.Match object; span=(0, 75), match='gemma-3-12B-lr0.003-20260529-seed19_target_concep>
# <re.Match object; span=(0, 86), match='gemma-3-12B-lr0.003-20260529-seed18_target_concep>
# <re.Match object; span=(0, 74), match='gemma-3-12B-lr0.003-20260529-seed4_target_concept>
# <re.Match object; span=(0, 86), match='gemma-3-12B-lr0.003-20260529-seed17_target_concep>
# <re.Match object; span=(0, 74), match='gemma-3-12B-lr0.003-20260529-seed5_target_concept>
# <re.Match object; span=(0, 75), match='gemma-3-12B-lr0.003-20260529-seed15_target_concep>
# <re.Match object; span=(0, 86), match='gemma-3-12B-lr0.003-20260529-seed10_target_concep>
# <re.Match object; span=(0, 85), match='gemma-3-12B-lr0.003-20260529-seed0_target_concept>
# <re.Match object; span=(0, 75), match='gemma-3-12B-lr0.003-20260529-seed10_target_concep>
# <re.Match object; span=(0, 85), match='gemma-3-12B-lr0.003-20260529-seed1_target_concept>
# <re.Match object; span=(0, 74), match='gemma-3-12B-lr0.003-20260529-seed9_target_concept>
# <re.Match object; span=(0, 74), match='gemma-3-12B-lr0.003-20260529-seed6_target_concept>
# <re.Match object; span=(0, 85), match='gemma-3-12B-lr0.003-20260529-seed8_target_concept>
# <re.Match object; span=(0, 86), match='gemma-3-12B-lr0.003-20260529-seed15_target_concep>
# <re.Match object; span=(0, 75), match='gemma-3-12B-lr0.003-20260529-seed16_target_concep>
# InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12
# InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 0, Average Accuracy at Epoch 2: 0.5982
# InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 1, Average Accuracy at Epoch 2: 0.6333
# InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 2, Average Accuracy at Epoch 2: 0.6307
# InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 3, Average Accuracy at Epoch 2: 0.6191
# InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 4, Average Accuracy at Epoch 2: 0.6342
# InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 5, Average Accuracy at Epoch 2: 0.6742
# InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 6, Average Accuracy at Epoch 2: 0.6569
# InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 7, Average Accuracy at Epoch 2: 0.6294
# InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 8, Average Accuracy at Epoch 2: 0.6382
# InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 9, Average Accuracy at Epoch 2: 0.6898
# InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 10, Average Accuracy at Epoch 2: 0.6340
# InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 11, Average Accuracy at Epoch 2: 0.6508
# InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 12, Average Accuracy at Epoch 2: 0.5923
# InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 13, Average Accuracy at Epoch 2: 0.6266
# InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 14, Average Accuracy at Epoch 2: 0.6375
# InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 15, Average Accuracy at Epoch 2: 0.6223
# InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 16, Average Accuracy at Epoch 2: 0.6741
# InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 17, Average Accuracy at Epoch 2: 0.5979
# InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 18, Average Accuracy at Epoch 2: 0.6644
# InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 19, Average Accuracy at Epoch 2: 0.6411
# 	 [0.5981864737590823, 0.6332531005717771, 0.6307370291464358, 0.6191408318264986, 0.6342283033994716, 0.6742337346943035, 0.6568844902545071, 0.629393244713287, 0.6381839531220054, 0.6897655798412372, 0.6340344625332792, 0.6507757396035208, 0.5922565194803252, 0.6265517767638216, 0.6374727092725585, 0.6223085090753695, 0.6740648592294145, 0.5978728147827713, 0.6643665935641659, 0.6411371081065138]
# 	accuracy at epoch 2: 0.6372 ± 0.0252
#
# InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 0, Average Accuracy at Epoch 2: 0.6302
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 1, Average Accuracy at Epoch 2: 0.6146
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 2, Average Accuracy at Epoch 2: 0.6420
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 3, Average Accuracy at Epoch 2: 0.6324
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 4, Average Accuracy at Epoch 2: 0.5876
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 5, Average Accuracy at Epoch 2: 0.6401
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 6, Average Accuracy at Epoch 2: 0.6470
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 7, Average Accuracy at Epoch 2: 0.6468
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 8, Average Accuracy at Epoch 2: 0.6006
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 9, Average Accuracy at Epoch 2: 0.6101
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 10, Average Accuracy at Epoch 2: 0.6364
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 11, Average Accuracy at Epoch 2: 0.5872
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 12, Average Accuracy at Epoch 2: 0.6173
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 13, Average Accuracy at Epoch 2: 0.6165
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 14, Average Accuracy at Epoch 2: 0.6519
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 15, Average Accuracy at Epoch 2: 0.6621
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 16, Average Accuracy at Epoch 2: 0.5837
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 17, Average Accuracy at Epoch 2: 0.6222
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 18, Average Accuracy at Epoch 2: 0.6351
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 19, Average Accuracy at Epoch 2: 0.6584
# 	 [0.6302072139075041, 0.6146265953805818, 0.6419640958369232, 0.6324147427087057, 0.5875617417438285, 0.6401476858643664, 0.6470116941229599, 0.6468275846037254, 0.6005886295240125, 0.6100824381798573, 0.6364213556049502, 0.587199802104446, 0.6172925169998542, 0.6165051243936931, 0.651881916681421, 0.6621075028751698, 0.5836809206936603, 0.6221918408588637, 0.6350949638636091, 0.6583766491056715]
# 	accuracy at epoch 2: 0.6261 ± 0.0230
#
# InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 0, Average Accuracy at Epoch 2: 0.6066
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 1, Average Accuracy at Epoch 2: 0.6169
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 2, Average Accuracy at Epoch 2: 0.6297
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 3, Average Accuracy at Epoch 2: 0.6535
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 4, Average Accuracy at Epoch 2: 0.6559
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 5, Average Accuracy at Epoch 2: 0.6006
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 6, Average Accuracy at Epoch 2: 0.6178
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 7, Average Accuracy at Epoch 2: 0.6424
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 8, Average Accuracy at Epoch 2: 0.6092
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 9, Average Accuracy at Epoch 2: 0.6279
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 10, Average Accuracy at Epoch 2: 0.6125
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 11, Average Accuracy at Epoch 2: 0.6367
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 12, Average Accuracy at Epoch 2: 0.6230
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 13, Average Accuracy at Epoch 2: 0.6059
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 14, Average Accuracy at Epoch 2: 0.6525
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 15, Average Accuracy at Epoch 2: 0.6085
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 16, Average Accuracy at Epoch 2: 0.6107
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 17, Average Accuracy at Epoch 2: 0.6063
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 18, Average Accuracy at Epoch 2: 0.6312
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 19, Average Accuracy at Epoch 2: 0.6290
# 	 [0.6065681173331037, 0.6169120843088833, 0.6297241828175454, 0.6534645396782943, 0.6558885768851346, 0.6005858311692793, 0.6178125947671377, 0.6423712335779146, 0.6091643931545832, 0.6279396800910289, 0.6124884788296285, 0.6366946615235185, 0.6230031413387507, 0.6059068035169959, 0.6524650370460162, 0.6085023828248709, 0.6107105085133318, 0.606251808041441, 0.6311856339835036, 0.6290286581190501]
# 	accuracy at epoch 2: 0.6238 ± 0.0168
#
# InitVecType: norm_rand_vocab
# 	InitVecType: norm_rand_vocab, Seed: 0, Average Accuracy at Epoch 2: 0.6319
# 	InitVecType: norm_rand_vocab, Seed: 1, Average Accuracy at Epoch 2: 0.6602
# 	InitVecType: norm_rand_vocab, Seed: 2, Average Accuracy at Epoch 2: 0.5732
# 	InitVecType: norm_rand_vocab, Seed: 3, Average Accuracy at Epoch 2: 0.5866
# 	InitVecType: norm_rand_vocab, Seed: 4, Average Accuracy at Epoch 2: 0.6001
# 	InitVecType: norm_rand_vocab, Seed: 5, Average Accuracy at Epoch 2: 0.6077
# 	InitVecType: norm_rand_vocab, Seed: 6, Average Accuracy at Epoch 2: 0.5822
# 	InitVecType: norm_rand_vocab, Seed: 7, Average Accuracy at Epoch 2: 0.6114
# 	InitVecType: norm_rand_vocab, Seed: 8, Average Accuracy at Epoch 2: 0.5881
# 	InitVecType: norm_rand_vocab, Seed: 9, Average Accuracy at Epoch 2: 0.5694
# 	InitVecType: norm_rand_vocab, Seed: 10, Average Accuracy at Epoch 2: 0.5754
# 	InitVecType: norm_rand_vocab, Seed: 11, Average Accuracy at Epoch 2: 0.5997
# 	InitVecType: norm_rand_vocab, Seed: 12, Average Accuracy at Epoch 2: 0.6544
# 	InitVecType: norm_rand_vocab, Seed: 13, Average Accuracy at Epoch 2: 0.5883
# 	InitVecType: norm_rand_vocab, Seed: 14, Average Accuracy at Epoch 2: 0.6317
# 	InitVecType: norm_rand_vocab, Seed: 15, Average Accuracy at Epoch 2: 0.6202
# 	InitVecType: norm_rand_vocab, Seed: 16, Average Accuracy at Epoch 2: 0.5567
# 	InitVecType: norm_rand_vocab, Seed: 17, Average Accuracy at Epoch 2: 0.6218
# 	InitVecType: norm_rand_vocab, Seed: 18, Average Accuracy at Epoch 2: 0.5861
# 	InitVecType: norm_rand_vocab, Seed: 19, Average Accuracy at Epoch 2: 0.5992
# 	 [0.631901196242757, 0.6602075956022263, 0.5731886842871332, 0.5865703633670135, 0.6000668244129262, 0.6077339292842432, 0.582205919633596, 0.6114031523517558, 0.5880558306411946, 0.5693533558671456, 0.5753984890676771, 0.5996841677838026, 0.6544208336331807, 0.5882677150204989, 0.6317203614376757, 0.6201857192362543, 0.5567207418722062, 0.6218266238235739, 0.5861249513670079, 0.5991957550017639]
# 	accuracy at epoch 2: 0.6022 ± 0.0271
#
# InitVecType: zero
# 	InitVecType: zero, Seed: 0, Average Accuracy at Epoch 2: 0.5708
# 	InitVecType: zero, Seed: 1, Average Accuracy at Epoch 2: 0.5163
# 	InitVecType: zero, Seed: 2, Average Accuracy at Epoch 2: 0.5585
# 	InitVecType: zero, Seed: 3, Average Accuracy at Epoch 2: 0.5127
# 	InitVecType: zero, Seed: 4, Average Accuracy at Epoch 2: 0.5091
# 	InitVecType: zero, Seed: 5, Average Accuracy at Epoch 2: 0.5379
# 	InitVecType: zero, Seed: 6, Average Accuracy at Epoch 2: 0.5591
# 	InitVecType: zero, Seed: 7, Average Accuracy at Epoch 2: 0.5819
# 	InitVecType: zero, Seed: 8, Average Accuracy at Epoch 2: 0.5377
# 	InitVecType: zero, Seed: 9, Average Accuracy at Epoch 2: 0.5080
# 	InitVecType: zero, Seed: 10, Average Accuracy at Epoch 2: 0.5440
# 	InitVecType: zero, Seed: 11, Average Accuracy at Epoch 2: 0.5842
# 	InitVecType: zero, Seed: 12, Average Accuracy at Epoch 2: 0.5440
# 	InitVecType: zero, Seed: 13, Average Accuracy at Epoch 2: 0.5562
# 	InitVecType: zero, Seed: 14, Average Accuracy at Epoch 2: 0.5266
# 	InitVecType: zero, Seed: 15, Average Accuracy at Epoch 2: 0.5554
# 	InitVecType: zero, Seed: 16, Average Accuracy at Epoch 2: 0.5898
# 	InitVecType: zero, Seed: 17, Average Accuracy at Epoch 2: 0.5616
# 	InitVecType: zero, Seed: 18, Average Accuracy at Epoch 2: 0.5729
# 	InitVecType: zero, Seed: 19, Average Accuracy at Epoch 2: 0.4846
# 	 [0.5708260133012245, 0.5163114546456075, 0.5585421488361966, 0.5127336039554439, 0.509068351882144, 0.5379114550174203, 0.5591261272319754, 0.5819436492633744, 0.5376900484776231, 0.5079662448663274, 0.5440170673429023, 0.5842074374021355, 0.5439507066929613, 0.5561562300239535, 0.5266434506848078, 0.5553911903560654, 0.5897542955073506, 0.5616182115070004, 0.5728973808086388, 0.484585997691372]
# 	accuracy at epoch 2: 0.5456 ± 0.0282
#
# ==============================
# ==============================
#
# Epoch: 3
# <re.Match object; span=(0, 75), match='gemma-3-12B-lr0.003-20260529-seed13_target_concep>
# <re.Match object; span=(0, 85), match='gemma-3-12B-lr0.003-20260529-seed3_target_concept>
# <re.Match object; span=(0, 75), match='gemma-3-12B-lr0.003-20260529-seed18_target_concep>
# <re.Match object; span=(0, 85), match='gemma-3-12B-lr0.003-20260529-seed5_target_concept>
# <re.Match object; span=(0, 86), match='gemma-3-12B-lr0.003-20260529-seed13_target_concep>
# <re.Match object; span=(0, 74), match='gemma-3-12B-lr0.003-20260529-seed8_target_concept>
# <re.Match object; span=(0, 74), match='gemma-3-12B-lr0.003-20260529-seed2_target_concept>
# <re.Match object; span=(0, 85), match='gemma-3-12B-lr0.003-20260529-seed9_target_concept>
# <re.Match object; span=(0, 86), match='gemma-3-12B-lr0.003-20260529-seed11_target_concep>
# <re.Match object; span=(0, 74), match='gemma-3-12B-lr0.003-20260529-seed7_target_concept>
# <re.Match object; span=(0, 75), match='gemma-3-12B-lr0.003-20260529-seed14_target_concep>
# <re.Match object; span=(0, 86), match='gemma-3-12B-lr0.003-20260529-seed19_target_concep>
# <re.Match object; span=(0, 75), match='gemma-3-12B-lr0.003-20260529-seed12_target_concep>
# <re.Match object; span=(0, 85), match='gemma-3-12B-lr0.003-20260529-seed7_target_concept>
# <re.Match object; span=(0, 85), match='gemma-3-12B-lr0.003-20260529-seed4_target_concept>
# <re.Match object; span=(0, 86), match='gemma-3-12B-lr0.003-20260529-seed16_target_concep>
# <re.Match object; span=(0, 74), match='gemma-3-12B-lr0.003-20260529-seed1_target_concept>
# <re.Match object; span=(0, 85), match='gemma-3-12B-lr0.003-20260529-seed6_target_concept>
# <re.Match object; span=(0, 75), match='gemma-3-12B-lr0.003-20260529-seed11_target_concep>
# <re.Match object; span=(0, 74), match='gemma-3-12B-lr0.003-20260529-seed3_target_concept>
# <re.Match object; span=(0, 86), match='gemma-3-12B-lr0.003-20260529-seed14_target_concep>
# ...
# 	 [0.6381317381516407, 0.6739576941474581, 0.6734688824774693, 0.6275870597579105, 0.609442942596305, 0.655105477174216, 0.6265996156889833, 0.703205120401883, 0.6674699185809286, 0.6398688686461025, 0.6252380970944541, 0.6851764326364875, 0.6413361635885031, 0.654975486361545, 0.640069666738609, 0.6454411631486531, 0.711065910375861, 0.6432947584570077, 0.6127871888460144, 0.6320810370901706]
# 	accuracy at epoch 9: 0.6503 ± 0.0272
#
# ==============================
# ==============================
#
# Epoch: 10
# <re.Match object; span=(0, 75), match='gemma-3-12B-lr0.003-20260529-seed13_target_concep>
# <re.Match object; span=(0, 85), match='gemma-3-12B-lr0.003-20260529-seed3_target_concept>
# <re.Match object; span=(0, 75), match='gemma-3-12B-lr0.003-20260529-seed18_target_concep>
# <re.Match object; span=(0, 85), match='gemma-3-12B-lr0.003-20260529-seed5_target_concept>
# <re.Match object; span=(0, 86), match='gemma-3-12B-lr0.003-20260529-seed13_target_concep>
# <re.Match object; span=(0, 74), match='gemma-3-12B-lr0.003-20260529-seed8_target_concept>
# <re.Match object; span=(0, 74), match='gemma-3-12B-lr0.003-20260529-seed2_target_concept>
# <re.Match object; span=(0, 85), match='gemma-3-12B-lr0.003-20260529-seed9_target_concept>
# <re.Match object; span=(0, 86), match='gemma-3-12B-lr0.003-20260529-seed11_target_concep>
# <re.Match object; span=(0, 74), match='gemma-3-12B-lr0.003-20260529-seed7_target_concept>
# <re.Match object; span=(0, 75), match='gemma-3-12B-lr0.003-20260529-seed14_target_concep>
# <re.Match object; span=(0, 86), match='gemma-3-12B-lr0.003-20260529-seed19_target_concep>
# <re.Match object; span=(0, 75), match='gemma-3-12B-lr0.003-20260529-seed12_target_concep>
# <re.Match object; span=(0, 85), match='gemma-3-12B-lr0.003-20260529-seed7_target_concept>
# <re.Match object; span=(0, 85), match='gemma-3-12B-lr0.003-20260529-seed4_target_concept>
# <re.Match object; span=(0, 86), match='gemma-3-12B-lr0.003-20260529-seed16_target_concep>
# <re.Match object; span=(0, 74), match='gemma-3-12B-lr0.003-20260529-seed1_target_concept>
# <re.Match object; span=(0, 85), match='gemma-3-12B-lr0.003-20260529-seed6_target_concept>
# <re.Match object; span=(0, 75), match='gemma-3-12B-lr0.003-20260529-seed11_target_concep>
# <re.Match object; span=(0, 74), match='gemma-3-12B-lr0.003-20260529-seed3_target_concept>
# <re.Match object; span=(0, 86), match='gemma-3-12B-lr0.003-20260529-seed14_target_concep>
# <re.Match object; span=(0, 86), match='gemma-3-12B-lr0.003-20260529-seed12_target_concep>
# <re.Match object; span=(0, 85), match='gemma-3-12B-lr0.003-20260529-seed2_target_concept>
# <re.Match object; span=(0, 74), match='gemma-3-12B-lr0.003-20260529-seed0_target_concept>
# <re.Match object; span=(0, 75), match='gemma-3-12B-lr0.003-20260529-seed17_target_concep>
# <re.Match object; span=(0, 75), match='gemma-3-12B-lr0.003-20260529-seed19_target_concep>
# <re.Match object; span=(0, 86), match='gemma-3-12B-lr0.003-20260529-seed18_target_concep>
# <re.Match object; span=(0, 74), match='gemma-3-12B-lr0.003-20260529-seed4_target_concept>
# <re.Match object; span=(0, 86), match='gemma-3-12B-lr0.003-20260529-seed17_target_concep>
# <re.Match object; span=(0, 74), match='gemma-3-12B-lr0.003-20260529-seed5_target_concept>
# <re.Match object; span=(0, 75), match='gemma-3-12B-lr0.003-20260529-seed15_target_concep>
# <re.Match object; span=(0, 86), match='gemma-3-12B-lr0.003-20260529-seed10_target_concep>
# <re.Match object; span=(0, 85), match='gemma-3-12B-lr0.003-20260529-seed0_target_concept>
# <re.Match object; span=(0, 75), match='gemma-3-12B-lr0.003-20260529-seed10_target_concep>
# <re.Match object; span=(0, 85), match='gemma-3-12B-lr0.003-20260529-seed1_target_concept>
# <re.Match object; span=(0, 74), match='gemma-3-12B-lr0.003-20260529-seed9_target_concept>
# <re.Match object; span=(0, 74), match='gemma-3-12B-lr0.003-20260529-seed6_target_concept>
# <re.Match object; span=(0, 85), match='gemma-3-12B-lr0.003-20260529-seed8_target_concept>
# <re.Match object; span=(0, 86), match='gemma-3-12B-lr0.003-20260529-seed15_target_concep>
# <re.Match object; span=(0, 75), match='gemma-3-12B-lr0.003-20260529-seed16_target_concep>
# InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12
# InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 0, Average Accuracy at Epoch 10: 0.6526
# InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 1, Average Accuracy at Epoch 10: 0.7086
# InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 2, Average Accuracy at Epoch 10: 0.6904
# InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 3, Average Accuracy at Epoch 10: 0.6908
# InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 4, Average Accuracy at Epoch 10: 0.6810
# InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 5, Average Accuracy at Epoch 10: 0.7203
# InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 6, Average Accuracy at Epoch 10: 0.7305
# InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 7, Average Accuracy at Epoch 10: 0.7076
# InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 8, Average Accuracy at Epoch 10: 0.6871
# InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 9, Average Accuracy at Epoch 10: 0.7027
# InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 10, Average Accuracy at Epoch 10: 0.6509
# InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 11, Average Accuracy at Epoch 10: 0.7192
# InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 12, Average Accuracy at Epoch 10: 0.7095
# InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 13, Average Accuracy at Epoch 10: 0.6859
# InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 14, Average Accuracy at Epoch 10: 0.6886
# InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 15, Average Accuracy at Epoch 10: 0.7155
# InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 16, Average Accuracy at Epoch 10: 0.7571
# InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 17, Average Accuracy at Epoch 10: 0.7056
# InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 18, Average Accuracy at Epoch 10: 0.7076
# InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 19, Average Accuracy at Epoch 10: 0.6861
# 	 [0.6525644649653219, 0.7085702813472099, 0.6903791160993659, 0.6907867683538039, 0.6810377486802561, 0.7203131536025205, 0.730522665905754, 0.7075869271599449, 0.687092805803198, 0.7027300487769088, 0.65086568117159, 0.7191504112913066, 0.7095252916795887, 0.6858835728147435, 0.6886244820742271, 0.7155063397191983, 0.757120224503925, 0.705591715610984, 0.707565586936036, 0.6861395635187685]
# 	accuracy at epoch 10: 0.6999 ± 0.0239
#
# InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 0, Average Accuracy at Epoch 10: 0.6931
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 1, Average Accuracy at Epoch 10: 0.6410
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 2, Average Accuracy at Epoch 10: 0.6999
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 3, Average Accuracy at Epoch 10: 0.6989
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 4, Average Accuracy at Epoch 10: 0.6390
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 5, Average Accuracy at Epoch 10: 0.6968
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 6, Average Accuracy at Epoch 10: 0.7150
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 7, Average Accuracy at Epoch 10: 0.7043
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 8, Average Accuracy at Epoch 10: 0.6421
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 9, Average Accuracy at Epoch 10: 0.7003
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 10, Average Accuracy at Epoch 10: 0.7184
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 11, Average Accuracy at Epoch 10: 0.6683
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 12, Average Accuracy at Epoch 10: 0.6855
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 13, Average Accuracy at Epoch 10: 0.6729
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 14, Average Accuracy at Epoch 10: 0.7034
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 15, Average Accuracy at Epoch 10: 0.7249
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 16, Average Accuracy at Epoch 10: 0.6498
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 17, Average Accuracy at Epoch 10: 0.6714
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 18, Average Accuracy at Epoch 10: 0.6964
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 19, Average Accuracy at Epoch 10: 0.6949
# 	 [0.6930788584164009, 0.6410403452059731, 0.6999331400640799, 0.6988795545838727, 0.6390368435375121, 0.6967689930486463, 0.7150215709183763, 0.7043346214909759, 0.6421176913706236, 0.7003020250104677, 0.7184355913313341, 0.6683332782949332, 0.6855315937407688, 0.6729437089604982, 0.7034451175595048, 0.7248698285925408, 0.6497790565107509, 0.6713663669717469, 0.696402833592026, 0.6949169350376897]
# 	accuracy at epoch 10: 0.6858 ± 0.0256
#
# InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 0, Average Accuracy at Epoch 10: 0.7145
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 1, Average Accuracy at Epoch 10: 0.6572
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 2, Average Accuracy at Epoch 10: 0.7016
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 3, Average Accuracy at Epoch 10: 0.6912
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 4, Average Accuracy at Epoch 10: 0.7200
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 5, Average Accuracy at Epoch 10: 0.6859
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 6, Average Accuracy at Epoch 10: 0.6721
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 7, Average Accuracy at Epoch 10: 0.7238
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 8, Average Accuracy at Epoch 10: 0.6883
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 9, Average Accuracy at Epoch 10: 0.6838
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 10, Average Accuracy at Epoch 10: 0.6459
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 11, Average Accuracy at Epoch 10: 0.6843
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 12, Average Accuracy at Epoch 10: 0.7016
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 13, Average Accuracy at Epoch 10: 0.6999
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 14, Average Accuracy at Epoch 10: 0.7156
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 15, Average Accuracy at Epoch 10: 0.6887
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 16, Average Accuracy at Epoch 10: 0.6844
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 17, Average Accuracy at Epoch 10: 0.6983
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 18, Average Accuracy at Epoch 10: 0.7277
# 	InitVecType: farCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 19, Average Accuracy at Epoch 10: 0.7017
# 	 [0.7145384952131603, 0.6572166063903192, 0.7015570446307919, 0.6912449501485433, 0.7199818333965854, 0.6859005939452445, 0.6721026000196854, 0.7238485583054458, 0.6882884908883298, 0.6838171737435028, 0.6459071154462072, 0.6843006544729734, 0.7015631322930561, 0.6999125149761927, 0.7155661869052403, 0.6886903172938003, 0.684407758720667, 0.6983084958860574, 0.727717724412736, 0.7017295786796875]
# 	accuracy at epoch 10: 0.6943 ± 0.0205
#
# InitVecType: norm_rand_vocab
# 	InitVecType: norm_rand_vocab, Seed: 0, Average Accuracy at Epoch 10: 0.6673
# 	InitVecType: norm_rand_vocab, Seed: 1, Average Accuracy at Epoch 10: 0.6690
# 	InitVecType: norm_rand_vocab, Seed: 2, Average Accuracy at Epoch 10: 0.6310
# 	InitVecType: norm_rand_vocab, Seed: 3, Average Accuracy at Epoch 10: 0.6212
# 	InitVecType: norm_rand_vocab, Seed: 4, Average Accuracy at Epoch 10: 0.6796
# 	InitVecType: norm_rand_vocab, Seed: 5, Average Accuracy at Epoch 10: 0.7252
# 	InitVecType: norm_rand_vocab, Seed: 6, Average Accuracy at Epoch 10: 0.6965
# 	InitVecType: norm_rand_vocab, Seed: 7, Average Accuracy at Epoch 10: 0.7050
# 	InitVecType: norm_rand_vocab, Seed: 8, Average Accuracy at Epoch 10: 0.6662
# 	InitVecType: norm_rand_vocab, Seed: 9, Average Accuracy at Epoch 10: 0.6669
# 	InitVecType: norm_rand_vocab, Seed: 10, Average Accuracy at Epoch 10: 0.6424
# 	InitVecType: norm_rand_vocab, Seed: 11, Average Accuracy at Epoch 10: 0.6669
# 	InitVecType: norm_rand_vocab, Seed: 12, Average Accuracy at Epoch 10: 0.6845
# 	InitVecType: norm_rand_vocab, Seed: 13, Average Accuracy at Epoch 10: 0.6617
# 	InitVecType: norm_rand_vocab, Seed: 14, Average Accuracy at Epoch 10: 0.7066
# 	InitVecType: norm_rand_vocab, Seed: 15, Average Accuracy at Epoch 10: 0.6596
# 	InitVecType: norm_rand_vocab, Seed: 16, Average Accuracy at Epoch 10: 0.6669
# 	InitVecType: norm_rand_vocab, Seed: 17, Average Accuracy at Epoch 10: 0.6679
# 	InitVecType: norm_rand_vocab, Seed: 18, Average Accuracy at Epoch 10: 0.6597
# 	InitVecType: norm_rand_vocab, Seed: 19, Average Accuracy at Epoch 10: 0.6556
# 	 [0.6672664238101429, 0.6689696109146447, 0.6309873240806396, 0.6212249244364796, 0.6795766808204153, 0.7252027483995496, 0.6965156859225347, 0.7050351874295997, 0.6661950422313458, 0.6668847184734585, 0.6423632173821455, 0.6668571218119627, 0.6845444361073914, 0.6617107000204567, 0.7066444941439081, 0.6595735830625618, 0.6668756628758374, 0.6678808357998892, 0.6597058875666433, 0.6556387929832298]
# 	accuracy at epoch 10: 0.6700 ± 0.0243
#
# InitVecType: zero
# 	InitVecType: zero, Seed: 0, Average Accuracy at Epoch 10: 0.6432
# 	InitVecType: zero, Seed: 1, Average Accuracy at Epoch 10: 0.6627
# 	InitVecType: zero, Seed: 2, Average Accuracy at Epoch 10: 0.6727
# 	InitVecType: zero, Seed: 3, Average Accuracy at Epoch 10: 0.6180
# 	InitVecType: zero, Seed: 4, Average Accuracy at Epoch 10: 0.5962
# 	InitVecType: zero, Seed: 5, Average Accuracy at Epoch 10: 0.6573
# 	InitVecType: zero, Seed: 6, Average Accuracy at Epoch 10: 0.6490
# 	InitVecType: zero, Seed: 7, Average Accuracy at Epoch 10: 0.6872
# 	InitVecType: zero, Seed: 8, Average Accuracy at Epoch 10: 0.6762
# 	InitVecType: zero, Seed: 9, Average Accuracy at Epoch 10: 0.6182
# 	InitVecType: zero, Seed: 10, Average Accuracy at Epoch 10: 0.6345
# 	InitVecType: zero, Seed: 11, Average Accuracy at Epoch 10: 0.6748
# 	InitVecType: zero, Seed: 12, Average Accuracy at Epoch 10: 0.6376
# 	InitVecType: zero, Seed: 13, Average Accuracy at Epoch 10: 0.6449
# 	InitVecType: zero, Seed: 14, Average Accuracy at Epoch 10: 0.6357
# 	InitVecType: zero, Seed: 15, Average Accuracy at Epoch 10: 0.6515
# 	InitVecType: zero, Seed: 16, Average Accuracy at Epoch 10: 0.7100
# 	InitVecType: zero, Seed: 17, Average Accuracy at Epoch 10: 0.6259
# 	InitVecType: zero, Seed: 18, Average Accuracy at Epoch 10: 0.6148
# 	InitVecType: zero, Seed: 19, Average Accuracy at Epoch 10: 0.6504
# 	 [0.6431912299547478, 0.662734637560227, 0.6726526747654742, 0.6179749196293146, 0.596202134453186, 0.6573481313417642, 0.6490224516007282, 0.6872264722209537, 0.67620794888367, 0.6182025946305711, 0.6345488463599016, 0.6748048767154258, 0.6375685689307938, 0.6449216500309282, 0.6356751418138997, 0.6514835989913588, 0.7100271599209691, 0.6258669169082384, 0.6147747707242467, 0.650379489156441]
# 	accuracy at epoch 10: 0.6480 ± 0.0268
#
# ==============================
# ==============================
#
# date: 20260529

# %%
print(cat_mean_accs)
# print(cat_std_accs)

print(nearcat_mean_accs)
# print(nearcat_std_accs)

print(farcat_mean_accs)
# print(farcat_std_accs)

print(norm_rand_vocab_mean_accs)
# print(norm_rand_vocab_std_accs)

print(zero_mean_accs)
# print(zero_std_accs)
# Out:
# [np.float64(0.4024050347064449), np.float64(0.576823391786635), np.float64(0.6372423916870174), np.float64(0.6615599037349953), np.float64(0.6779324661578581), np.float64(0.6844249194498462), np.float64(0.6903237972636094), np.float64(0.6942502356771476), np.float64(0.7004615221026211), np.float64(0.7038312549660886), np.float64(0.6998778425007327)]
# [np.float64(0.40379510245207023), np.float64(0.5688882160397543), np.float64(0.6261092507526903), np.float64(0.655800741774691), np.float64(0.6633518647098329), np.float64(0.6743623749646804), np.float64(0.6795265503286332), np.float64(0.6844426661439578), np.float64(0.6876091142976806), np.float64(0.6898884819367892), np.float64(0.6858268977119361)]
# [np.float64(0.40783144303296065), np.float64(0.5681431032317834), np.float64(0.6238334173760005), np.float64(0.6570800663013799), np.float64(0.6692299520368342), np.float64(0.6787089636379535), np.float64(0.68182987180244), np.float64(0.691351961763669), np.float64(0.6898461425947917), np.float64(0.6923992035435316), np.float64(0.6943299912884113)]
# [np.float64(0.4022889842263849), np.float64(0.5351444327215595), np.float64(0.6022116104966817), np.float64(0.6266032615204398), np.float64(0.639509974900048), np.float64(0.6548646331434277), np.float64(0.6579328692274707), np.float64(0.6647942686750462), np.float64(0.6710631271732537), np.float64(0.6693034774328342), np.float64(0.6699826539136418)]
# [np.float64(0.40800477739575464), np.float64(0.4941574214380096), np.float64(0.5455670532747262), np.float64(0.5699398826484858), np.float64(0.598839962252226), np.float64(0.6218532268146587), np.float64(0.6356567996254402), np.float64(0.6418991911020109), np.float64(0.6475274596375422), np.float64(0.6503151610980101), np.float64(0.648040710729642)]

# %%
for epoch in range(0, max_epoch+1):
    print(f"Epoch {epoch}:")
    print(f"  CatCent: {cat_mean_accs[epoch]:.4f} ± {cat_std_accs[epoch]:.4f}")
    print(f"  nearCatCent: {nearcat_mean_accs[epoch]:.4f} ± {nearcat_std_accs[epoch]:.4f}")
    print(f"  farCatCent: {farcat_mean_accs[epoch]:.4f} ± {farcat_std_accs[epoch]:.4f}")
    print(f"  norm_rand_vocab: {norm_rand_vocab_mean_accs[epoch]:.4f} ± {norm_rand_vocab_std_accs[epoch]:.4f}")
    print(f"  zero: {zero_mean_accs[epoch]:.4f} ± {zero_std_accs[epoch]:.4f}")
    print()
# Out:
# Epoch 0:
#   CatCent: 0.4024 ± 0.0020
#   nearCatCent: 0.4038 ± 0.0024
#   farCatCent: 0.4078 ± 0.0022
#   norm_rand_vocab: 0.4023 ± 0.0000
#   zero: 0.4080 ± 0.0000
#
# Epoch 1:
#   CatCent: 0.5768 ± 0.0280
#   nearCatCent: 0.5689 ± 0.0237
#   farCatCent: 0.5681 ± 0.0192
#   norm_rand_vocab: 0.5351 ± 0.0257
#   zero: 0.4942 ± 0.0250
#
# Epoch 2:
#   CatCent: 0.6372 ± 0.0252
#   nearCatCent: 0.6261 ± 0.0230
#   farCatCent: 0.6238 ± 0.0168
#   norm_rand_vocab: 0.6022 ± 0.0271
#   zero: 0.5456 ± 0.0282
#
# Epoch 3:
#   CatCent: 0.6616 ± 0.0275
#   nearCatCent: 0.6558 ± 0.0231
#   farCatCent: 0.6571 ± 0.0230
#   norm_rand_vocab: 0.6266 ± 0.0249
#   zero: 0.5699 ± 0.0251
#
# Epoch 4:
#   CatCent: 0.6779 ± 0.0234
#   nearCatCent: 0.6634 ± 0.0220
#   farCatCent: 0.6692 ± 0.0217
#   norm_rand_vocab: 0.6395 ± 0.0237
#   zero: 0.5988 ± 0.0278
#
# Epoch 5:
#   CatCent: 0.6844 ± 0.0207
#   nearCatCent: 0.6744 ± 0.0221
#   farCatCent: 0.6787 ± 0.0223
#   norm_rand_vocab: 0.6549 ± 0.0262
#   zero: 0.6219 ± 0.0304
#
# Epoch 6:
#   CatCent: 0.6903 ± 0.0227
#   nearCatCent: 0.6795 ± 0.0240
#   farCatCent: 0.6818 ± 0.0226
#   norm_rand_vocab: 0.6579 ± 0.0201
#   zero: 0.6357 ± 0.0304
#
# Epoch 7:
#   CatCent: 0.6943 ± 0.0232
#   nearCatCent: 0.6844 ± 0.0229
#   farCatCent: 0.6914 ± 0.0173
#   norm_rand_vocab: 0.6648 ± 0.0261
#   zero: 0.6419 ± 0.0245
#
# Epoch 8:
#   CatCent: 0.7005 ± 0.0256
#   nearCatCent: 0.6876 ± 0.0246
#   farCatCent: 0.6898 ± 0.0230
#   norm_rand_vocab: 0.6711 ± 0.0239
#   zero: 0.6475 ± 0.0300
#
# Epoch 9:
#   CatCent: 0.7038 ± 0.0184
#   nearCatCent: 0.6899 ± 0.0258
#   farCatCent: 0.6924 ± 0.0223
#   norm_rand_vocab: 0.6693 ± 0.0290
#   zero: 0.6503 ± 0.0272
#
# Epoch 10:
#   CatCent: 0.6999 ± 0.0239
#   nearCatCent: 0.6858 ± 0.0256
#   farCatCent: 0.6943 ± 0.0205
#   norm_rand_vocab: 0.6700 ± 0.0243
#   zero: 0.6480 ± 0.0268

# %% [markdown]
# ### Paired-t-test, Wilcoxon

# %%
import numpy as np
from scipy import stats

layer = 12
seed_num = 20
max_epoch = 10

# %% [markdown]
# #### CatCent - farCatCentの差の有意性検定

# %%
for epoch in range(0, max_epoch+1):
    print(f"Epoch: {epoch}")

    initvectype_to_seed_to_acc = load_file_and_calc_epoch_accs(date, epoch, lr=lr, 
                                                            target_concept_config_name=target_concept_config_name, 
                                                            model_size=model_size, 
                                                            result_dir=result_dir,
                                                            print_flag=False)

    # ** Cat **
    initVecType = f'CatCent_by_WikiSummaryRepeatHSMixed_layer{layer}'
    # print(f"InitVecType: {initVecType}")
    acc_lst = []
    for seed in range(seed_num):
        seed_to_acc = initvectype_to_seed_to_acc.get(initVecType, {})
        acc = seed_to_acc.get(seed, None)
        if acc is not None:
            acc_lst.append(acc)
            # print(f"InitVecType: {initVecType}, Seed: {seed}, Average Accuracy at Epoch {epoch}: {acc:.4f}")
        else:
            # print(f"\tInitVecType: {initVecType}, No data for Seed {seed}")
            pass
    print('\t', acc_lst)
    catcent_accs = np.array(acc_lst)
    

    # ** farCat ** [WIP] 4/27より後の実験はother -> farとしているため適宜ここも修正する
    initVecType = f'farCatCent_by_WikiSummaryRepeatHSMixed_layer{layer}'
    # print(f"InitVecType: {initVecType}")
    acc_lst = []
    for seed in range(seed_num):
        seed_to_acc = initvectype_to_seed_to_acc.get(initVecType, {})
        acc = seed_to_acc.get(seed, None)
        if acc is not None:
            acc_lst.append(acc)
            # print(f"\tInitVecType: {initVecType}, Seed: {seed}, Average Accuracy at Epoch {epoch}: {acc:.4f}")
        else:
            # print(f"\tInitVecType: {initVecType}, No data for Seed {seed}")
            pass
    print('\t', acc_lst)
    farcat_accs = np.array(acc_lst)


    diff = catcent_accs - farcat_accs

    # paired t-test
    t_stat, p_value = stats.ttest_rel(catcent_accs, farcat_accs)

    # Wilcoxon signed-rank test
    w_stat, p_wilcoxon = stats.wilcoxon(catcent_accs, farcat_accs)

    print("mean diff:", diff.mean())
    print("std diff:", diff.std(ddof=1))
    print("paired t-test p:", p_value)
    print("wilcoxon p:", p_wilcoxon)


    print('\n==============================\n==============================\n')
    

# どの日付のモデルが読み込まれたのかの確認用
print(f"date: {date}")
# Out:
# Epoch: 0
# 	 [0.40348249218601234, 0.404493059285288, 0.40119320299677674, 0.4032429414790388, 0.4022959421961636, 0.40431537647379034, 0.40266808708383994, 0.4031128278988025, 0.40211560250175743, 0.40176821491128345, 0.4021123486272951, 0.4049134565767742, 0.4010409623193421, 0.4002803385447865, 0.4036967414928658, 0.39747078855428924, 0.4006110547978793, 0.40108234333880055, 0.40080645354974087, 0.4073984593143712]
# 	 [0.4084080856379232, 0.4080785589407857, 0.40767725956208484, 0.4038182885763112, 0.41085722199846136, 0.40902250839445975, 0.4068835954160472, 0.40893168527374546, 0.40973757332477057, 0.4094850008692069, 0.4095961953291128, 0.41044961678168435, 0.40747749759728075, 0.4084960746868879, 0.40363407096874765, 0.4048392823333111, 0.40895373403888474, 0.4046153982089401, 0.41066486731875096, 0.40500234540181673]
# mean diff: -0.0054264083265157664
# std diff: 0.0031638917477499577
# paired t-test p: 3.114095283242607e-07
# wilcoxon p: 1.33514404296875e-05
#
# ==============================
# ==============================
#
# Epoch: 1
# 	 [0.5540758274737932, 0.6064654322160806, 0.5700890022176738, 0.5881198312373239, 0.6058971347226535, 0.5617735748582415, 0.5992485812617626, 0.5980686367459268, 0.5577816952064965, 0.5839067211780583, 0.5581468312210117, 0.5942450888010634, 0.5444067288688691, 0.5846578205118722, 0.5957173142258186, 0.6126214822100926, 0.6107698374071538, 0.5003987113974786, 0.5677101596912848, 0.542367424280047]
# 	 [0.5734627865997043, 0.5592837705470484, 0.6006955501622145, 0.561479904534351, 0.6037891124019686, 0.5698898821159832, 0.5539701231604643, 0.5787214240334273, 0.6001348418295134, 0.5511969962284561, 0.5458577822639168, 0.5543162881574519, 0.5720310661209083, 0.5500303189692458, 0.5755980391468378, 0.5687023948496253, 0.5260835224144972, 0.5602556729502147, 0.5870675888585718, 0.5702949992912697]
# mean diff: 0.008680288554851612
# std diff: 0.03702801563458287
# paired t-test p: 0.30761722858868945
# wilcoxon p: 0.3117942810058594
#
# ==============================
# ==============================
#
# Epoch: 2
# 	 [0.5981864737590823, 0.6332531005717771, 0.6307370291464358, 0.6191408318264986, 0.6342283033994716, 0.6742337346943035, 0.6568844902545071, 0.629393244713287, 0.6381839531220054, 0.6897655798412372, 0.6340344625332792, 0.6507757396035208, 0.5922565194803252, 0.6265517767638216, 0.6374727092725585, 0.6223085090753695, 0.6740648592294145, 0.5978728147827713, 0.6643665935641659, 0.6411371081065138]
# 	 [0.6065681173331037, 0.6169120843088833, 0.6297241828175454, 0.6534645396782943, 0.6558885768851346, 0.6005858311692793, 0.6178125947671377, 0.6423712335779146, 0.6091643931545832, 0.6279396800910289, 0.6124884788296285, 0.6366946615235185, 0.6230031413387507, 0.6059068035169959, 0.6524650370460162, 0.6085023828248709, 0.6107105085133318, 0.606251808041441, 0.6311856339835036, 0.6290286581190501]
# mean diff: 0.013408974311016692
# std diff: 0.030740199617887414
# paired t-test p: 0.06599205692796409
# wilcoxon p: 0.09730720520019531
#
# ==============================
# ==============================
#
# Epoch: 3
# 	 [0.583825995241089, 0.6830572114472842, 0.6787545513360291, 0.6547207729451312, 0.6561992389116204, 0.7008731747900286, 0.681065324190248, 0.6407615547975334, 0.6397964747108679, 0.6896801428244042, 0.6367922026016802, 0.6721240415502978, 0.6273210440096512, 0.6575528799692746, 0.6602718726858142, 0.6790149386099477, 0.7042309744858871, 0.6641079041190928, 0.6432447378667452, 0.6778030376072803]
# 	 [0.671241641508407, 0.6370370319837828, 0.6660094119799299, 0.6703604619546565, 0.692493227258187, 0.66832902048727, 0.6688663064133247, 0.700334228826536, 0.6495044391178129, 0.6342934175462471, 0.5971486479147801, 0.6560132670353281, 0.6365627084534874, 0.6537255997927406, 0.689966664072504, 0.6502061149972153, 0.6343523056398396, 0.6571812006094913, 0.6501509397478793, 0.6578246906881778]
# mean diff: 0.004479837433615491
# std diff: 0.0384035580449558
# paired t-test p: 0.6079202406903722
# wilcoxon p: 0.4304332733154297
#
# ==============================
# ==============================
#
# Epoch: 4
# 	 [0.6295023018681737, 0.7049658550453388, 0.6951182090905342, 0.6583849117365266, 0.6583505796396167, 0.6843347829698616, 0.6942021270309395, 0.6736182938825235, 0.6751660182057714, 0.6909260028086386, 0.6786350357731661, 0.6870512222394543, 0.66323393637869, 0.6879469996506258, 0.654302833976726, 0.7087567155140585, 0.7315049113824968, 0.6459274390451384, 0.6807553818712173, 0.6559657650476631]
# 	 [0.709382052338619, 0.6394603494946287, 0.6707000669461858, 0.6868027895171382, 0.7029491878172869, 0.6546105859431179, 0.6624864533056652, 0.7042018401262257, 0.6693598033545298, 0.6524387966624693, 0.6468532857877991, 0.6582243101345718, 0.639557804596252, 0.6581525117379994, 0.6798242228673204, 0.6502642843103537, 0.6576640632296655, 0.6835591746638788, 0.7025468994585276, 0.6555605584444515]
# mean diff: 0.00870251412102373
# std diff: 0.040778845261164334
# paired t-test p: 0.3518731947656477
# wilcoxon p: 0.3117942810058594
#
# ==============================
# ==============================
#
# Epoch: 5
# 	 [0.6482407582178029, 0.697986399228819, 0.6893606276099096, 0.6871675784355493, 0.6883734887152537, 0.6866279007237798, 0.7206737067219664, 0.6807213806149452, 0.6655153487094589, 0.7081005054615096, 0.6704654523718241, 0.674977517120182, 0.6583269540663449, 0.681369620994392, 0.6574797355884171, 0.6919397056187433, 0.7270877846727508, 0.6683433605558965, 0.7123918383454941, 0.6733487252238839]
# 	 [0.6636725865246409, 0.6667994433064288, 0.6643608315981668, 0.7071301466983135, 0.7135066260042748, 0.6996051560322306, 0.6741793536048762, 0.7162804875177632, 0.6525393704629702, 0.6801781216284289, 0.6359194506892115, 0.6816869202262537, 0.6576982680092421, 0.6563505885136535, 0.7102232327457073, 0.699507121055625, 0.6586329571720158, 0.6888851248921987, 0.6719209301209289, 0.675102555956139]
# mean diff: 0.005715955811892687
# std diff: 0.030956712000428002
# paired t-test p: 0.41919370974820136
# wilcoxon p: 0.49800872802734375
#
# ==============================
# ==============================
#
# Epoch: 6
# 	 [0.646800229500673, 0.6910789240235573, 0.6762899840073219, 0.7100381803302098, 0.6826380556884905, 0.7138737281434554, 0.717252769518307, 0.668509984929176, 0.6474209455886857, 0.6881444289512525, 0.6646469090547569, 0.6908189389475544, 0.6975788513275482, 0.6804451972637252, 0.6808224105913753, 0.7168502856970715, 0.7342140630917294, 0.7060157026919817, 0.7085781692413415, 0.6844581866839724]
# 	 [0.6965736313509786, 0.6635654897411793, 0.66379817079094, 0.6921364442370831, 0.7457735148712451, 0.682412907169388, 0.6678698765817457, 0.7226076242970123, 0.6675783769320299, 0.6684163738032095, 0.6485487836287048, 0.666356238117207, 0.6690023505345768, 0.6777243463322414, 0.6936388448097186, 0.7055427628636516, 0.6645624479423174, 0.6748067312728209, 0.6960323807753017, 0.6696501399974489]
# mean diff: 0.008493925461169238
# std diff: 0.03370171901085637
# paired t-test p: 0.27372433676562063
# wilcoxon p: 0.1893482208251953
#
# ==============================
# ==============================
#
# Epoch: 7
# 	 [0.64654433062619, 0.7200513134052327, 0.6899359880564949, 0.7058514656597752, 0.6651553222350477, 0.6987226866450883, 0.7179897294655834, 0.7122530800509269, 0.6839935370974646, 0.6898363223836632, 0.6613797572528153, 0.7077607735319439, 0.6853376454106781, 0.6745096722779216, 0.6760875615657037, 0.7261158732542176, 0.7383584668090026, 0.6725210379455421, 0.7039450877656445, 0.7086550621040159]
# 	 [0.7063608446424946, 0.6712932030357007, 0.6753816138414267, 0.697142466790784, 0.7188305792942108, 0.6844115296583302, 0.6857719705220465, 0.7161460281044433, 0.6781750179140802, 0.6610479038375152, 0.6695672921373205, 0.6714765304533371, 0.6853505177622121, 0.6873798850969486, 0.7147760944708403, 0.7181089252859978, 0.6935860287862103, 0.6865835393660924, 0.7083602644448075, 0.6972889998285813]
# mean diff: 0.002898273913478594
# std diff: 0.02950272035753635
# paired t-test p: 0.665377252135684
# wilcoxon p: 0.49800872802734375
#
# ==============================
# ==============================
#
# Epoch: 8
# 	 [0.6643208733100583, 0.7094119730907139, 0.676319147012808, 0.7154899572687662, 0.7116562055767677, 0.7046605225125769, 0.7321016175659492, 0.7032384112228149, 0.6752873660942866, 0.6784121990935869, 0.659508344876316, 0.7299211154219662, 0.6992537649111701, 0.6927902539327179, 0.6838284372054375, 0.7253338499278313, 0.7709046014709247, 0.6881419475216132, 0.6940170441968804, 0.6946328098392371]
# 	 [0.7232017604982043, 0.6597979514987138, 0.6881970076451664, 0.6969432928280663, 0.7308869228542959, 0.6845275895909241, 0.6659916235637411, 0.6973930710326102, 0.6944965398643761, 0.6599215764202468, 0.6398957699912126, 0.6958714801828647, 0.6900114011174311, 0.695065568810082, 0.7084630292114356, 0.7281395711410241, 0.6762235530873464, 0.6817229675508418, 0.7072184762113533, 0.6729536987958947]
# mean diff: 0.010615379507829592
# std diff: 0.03398910596359678
# paired t-test p: 0.17859919127564564
# wilcoxon p: 0.20244979858398438
#
# ==============================
# ==============================
#
# Epoch: 9
# 	 [0.6720737395040135, 0.7123558783665136, 0.7035530134366618, 0.7176896344428615, 0.7072083355654544, 0.7046104180996072, 0.7432222937562377, 0.6945018519610634, 0.6854756119036092, 0.7040492594695296, 0.6605101795638482, 0.7125048034477192, 0.7014213425492423, 0.7027455782402128, 0.7016041354921296, 0.707413757645395, 0.7388299394139032, 0.6895296368472654, 0.703367559103659, 0.7139581305128454]
# 	 [0.7157909932188287, 0.6725094217805994, 0.6801294247773286, 0.6987661128933996, 0.7356293024374364, 0.6733410396924201, 0.6790619288702998, 0.7242073792773808, 0.6775001003979202, 0.6655241420147004, 0.6540597019099154, 0.6760556859646342, 0.6878107975871982, 0.7099377441404049, 0.7197574778470244, 0.70535796668844, 0.6694858244043982, 0.6841594088884041, 0.7212540444346958, 0.6976455736452016]
# mean diff: 0.011432051422557061
# std diff: 0.03033889183914349
# paired t-test p: 0.1083136406298038
# wilcoxon p: 0.13272666931152344
#
# ==============================
# ==============================
#
# Epoch: 10
# 	 [0.6525644649653219, 0.7085702813472099, 0.6903791160993659, 0.6907867683538039, 0.6810377486802561, 0.7203131536025205, 0.730522665905754, 0.7075869271599449, 0.687092805803198, 0.7027300487769088, 0.65086568117159, 0.7191504112913066, 0.7095252916795887, 0.6858835728147435, 0.6886244820742271, 0.7155063397191983, 0.757120224503925, 0.705591715610984, 0.707565586936036, 0.6861395635187685]
# 	 [0.7145384952131603, 0.6572166063903192, 0.7015570446307919, 0.6912449501485433, 0.7199818333965854, 0.6859005939452445, 0.6721026000196854, 0.7238485583054458, 0.6882884908883298, 0.6838171737435028, 0.6459071154462072, 0.6843006544729734, 0.7015631322930561, 0.6999125149761927, 0.7155661869052403, 0.6886903172938003, 0.684407758720667, 0.6983084958860574, 0.727717724412736, 0.7017295786796875]
# mean diff: 0.005547851212321281
# std diff: 0.033762686028326654
# paired t-test p: 0.4714001501078928
# wilcoxon p: 0.6476554870605469
#
# ==============================
# ==============================
#
# date: 20260529

# %% [markdown]
# ### graph

# %%
import matplotlib.pyplot as plt
import japanize_matplotlib


cat_mean_accs = np.array(cat_mean_accs)
cat_std_accs = np.array(cat_std_accs)
nearcat_mean_accs = np.array(nearcat_mean_accs)
nearcat_std_accs = np.array(nearcat_std_accs)
farcat_mean_accs = np.array(farcat_mean_accs)
farcat_std_accs = np.array(farcat_std_accs)
zero_mean_accs = np.array(zero_mean_accs)
zero_std_accs = np.array(zero_std_accs)
norm_rand_vocab_mean_accs = np.array(norm_rand_vocab_mean_accs)
norm_rand_vocab_std_accs = np.array(norm_rand_vocab_std_accs)


epochs = list(range(0, max_epoch+1))

colors = {
    "同カテゴリ初期化": "tab:blue",
    "近カテゴリ初期化": "skyblue",
    "遠カテゴリ初期化": "tab:green",
    "ノルムランダム語彙初期化": "orange", #"black",
    "ゼロ初期化": "red" #"gray"
}
# ["tab:blue", "skyblue", "tab:green", "black", "gray"]

# %%
plt.figure(figsize=(8, 5))


# ["tab:blue", "skyblue", "tab:green", "black", "gray"]

for mean, std, label in [
    (cat_mean_accs, cat_std_accs, "同カテゴリ初期化"),
    (nearcat_mean_accs, nearcat_std_accs, "近カテゴリ初期化"),
    (farcat_mean_accs, farcat_std_accs, "遠カテゴリ初期化"),
    (zero_mean_accs, zero_std_accs, "ゼロ初期化"),
    (norm_rand_vocab_mean_accs, norm_rand_vocab_std_accs, "ノルムランダム語彙初期化"),
]:
    # print(len(epochs), len(mean))
    plt.plot(epochs, mean, marker="o", label=label, color=colors[label])
    # plt.fill_between(epochs, mean - std, mean + std, 
    #                 alpha=0.15, #0.12, 
    #                 color=colors[label], 
    #                 linewidth=2
    # )

plt.xlabel("Epoch")
plt.ylabel("Score")
plt.title("初期化手法ごとの性能推移")
plt.xticks(epochs)
plt.ylim(0, 1)
# チャンスレート 3選択肢分の0.33を追加
plt.axhline(0.33, color='gray', linestyle='--', label='Chance Rate')
plt.grid(True, alpha=0.3)
plt.legend(loc='lower right')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 5))

for mean, std, label in [
    (cat_mean_accs, cat_std_accs, "同カテゴリ初期化"),
    (nearcat_mean_accs, nearcat_std_accs, "近カテゴリ初期化"),
    (farcat_mean_accs, farcat_std_accs, "遠カテゴリ初期化"),
    (norm_rand_vocab_mean_accs, norm_rand_vocab_std_accs, "ノルムランダム語彙初期化"),
    (zero_mean_accs, zero_std_accs, "ゼロ初期化"),
]:
    # print(len(epochs), len(mean))
    plt.plot(epochs, mean, marker="o", label=label, color=colors[label])
    plt.fill_between(epochs, mean - std, mean + std, 
                    alpha=0.1, #0.15, #0.12, 
                    color=colors[label], 
                    linewidth=2
    )

    # # 上下の境界線を点線にする (fill_betweenの境界線はデフォルトでは実線になってしまうため、改めて点線で描画する)
    # plt.plot(epochs, mean - std, linestyle="--", color=colors[label], linewidth=1.2, alpha=0.6)
    # plt.plot(epochs, mean + std, linestyle="--", color=colors[label], linewidth=1.2, alpha=0.6)
    
plt.xlabel("Epoch")
plt.ylabel("Score")
plt.title("初期化手法ごとの性能推移 (標準偏差付き)")
plt.xticks(epochs)
plt.ylim(0.5, 0.8)
# チャンスレート 3選択肢分の0.33を追加
plt.axhline(0.33, color='gray', linestyle='--', label='Chance Rate')
plt.grid(True, alpha=0.3)
plt.legend(loc='lower right')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 5))

for mean, std, label in [
    (cat_mean_accs, cat_std_accs, "同カテゴリ初期化"),
    # (nearcat_mean_accs, nearcat_std_accs, "近カテゴリ初期化"),
    (farcat_mean_accs, farcat_std_accs, "遠カテゴリ初期化"),
    # (norm_rand_vocab_mean_accs, norm_rand_vocab_std_accs, "ノルムランダム語彙初期化"),
    # (zero_mean_accs, zero_std_accs, "ゼロ初期化"),
]:
    # print(len(epochs), len(mean))
    plt.plot(epochs, mean, marker="o", label=label, color=colors[label])
    plt.fill_between(epochs, mean - std, mean + std, 
                    alpha=0.15, #0.12, 
                    color=colors[label], 
                    linewidth=2
    )

    # # 上下の境界線を点線にする (fill_betweenの境界線はデフォルトでは実線になってしまうため、改めて点線で描画する)
    # plt.plot(epochs, mean - std, linestyle="--", color=colors[label], linewidth=1.2, alpha=0.6)
    # plt.plot(epochs, mean + std, linestyle="--", color=colors[label], linewidth=1.2, alpha=0.6)


plt.xlabel("Epoch")
plt.ylabel("Score")
plt.title("初期化手法ごとの性能推移 (標準偏差付き)")
plt.xticks(epochs)
plt.ylim(0.5, 0.8)
# チャンスレート 3選択肢分の0.33を追加
plt.axhline(0.33, color='gray', linestyle='--', label='Chance Rate')
plt.grid(True, alpha=0.3)
plt.legend(loc='lower right')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 5))

for mean, std, label in [
    (cat_mean_accs, cat_std_accs, "同カテゴリ初期化"),
    # (nearcat_mean_accs, nearcat_std_accs, "近カテゴリ初期化"),
    # (farcat_mean_accs, farcat_std_accs, "遠カテゴリ初期化"),
    (norm_rand_vocab_mean_accs, norm_rand_vocab_std_accs, "ノルムランダム語彙初期化"),
    # (zero_mean_accs, zero_std_accs, "ゼロ初期化"),
]:
    # print(len(epochs), len(mean))
    plt.plot(epochs, mean, marker="o", label=label, color=colors[label])
    plt.fill_between(epochs, mean - std, mean + std, 
                    alpha=0.15, #0.12, 
                    color=colors[label], 
                    linewidth=2
    )

    # # 上下の境界線を点線にする (fill_betweenの境界線はデフォルトでは実線になってしまうため、改めて点線で描画する)
    # plt.plot(epochs, mean - std, linestyle="--", color=colors[label], linewidth=1.2, alpha=0.6)
    # plt.plot(epochs, mean + std, linestyle="--", color=colors[label], linewidth=1.2, alpha=0.6)


plt.xlabel("Epoch")
plt.ylabel("Score")
plt.title("初期化手法ごとの性能推移 (標準偏差付き)")
plt.xticks(epochs)
plt.ylim(0.5, 0.8)
# チャンスレート 3選択肢分の0.33を追加
plt.axhline(0.33, color='gray', linestyle='--', label='Chance Rate')
plt.grid(True, alpha=0.3)
plt.legend(loc='lower right')
plt.tight_layout()
plt.show()

# %%
# 各手法の安定感 (stdが小さいほど安定)

same_cv = np.mean(cat_std_accs / cat_mean_accs)
# near_cv = np.mean(nearcat_std_accs / nearcat_mean_accs)
far_cv  = np.mean(farcat_std_accs / farcat_mean_accs)
norm_rand_vocab_cv = np.mean(norm_rand_vocab_std_accs / norm_rand_vocab_mean_accs)
zero_cv = np.mean(zero_std_accs / zero_mean_accs)
print("\n変動係数CV (std/mean) の平均値:")
print(f"同カテゴリ初期化: {same_cv:.4f}")
# print(f"近カテゴリ初期化: {near_cv:.4f}")
print(f"遠カテゴリ初期化: {far_cv:.4f}")
print(f"ノルムランダム語彙初期化: {norm_rand_vocab_cv:.4f}")
print(f"ゼロ初期化: {zero_cv:.4f}")
# Out:
# 変動係数CV (std/mean) の平均値:
# 同カテゴリ初期化: 0.0338
# 遠カテゴリ初期化: 0.0321
# ノルムランダム語彙初期化: 0.0349
# ゼロ初期化: 0.0424

# %%
plt.plot(epochs, cat_std_accs, label="同カテゴリ")
# plt.plot(epochs, nearcat_std_accs, label="近カテゴリ")
plt.plot(epochs, farcat_std_accs, label="遠カテゴリ")
plt.plot(epochs, norm_rand_vocab_std_accs, label="ノルムランダム語彙")
plt.plot(epochs, zero_std_accs, label="ゼロ")

plt.xlabel("Epoch")
plt.ylabel("Std (ばらつき)")
plt.title("ばらつきの推移")
plt.legend()
plt.show()
