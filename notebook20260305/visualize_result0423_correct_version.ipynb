# %% [markdown]
# # 最高到達accuracyを取得する

# %%
from datetime import date

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import os
import json
import re
import sys
from collections import defaultdict

project_root = os.path.join(os.getcwd(), "..")
result_dir = os.path.join(project_root, "results")


def load_file_and_extract_max_accs(date, lr, target_concept_config_name, model_size, result_dir):
    """各initVecTypeとseedに対して、回したepochs中の最高到達accuracyを抽出する関数"""
    # if target_concept_config_type != '':
    #     target_concept_config_type = '-' + target_concept_config_type
    # dirname_pattern1 = f"gemma-3-{model_size}B-lr0.01{target_concept_config_type}-{date}-hidden_layer(-?\\d+)-seed(\\d+)_target_concepts_initvecwith(.*)"
    # dirname_pattern2 = f"gemma-3-{model_size}B-lr0.01{target_concept_config_type}-{date}-seed(\\d+)_target_concepts_initvecwith(.*)"

    target_concept_config_name = target_concept_config_name.replace('.json', '')
    dirname_pattern1 = f"gemma-3-{model_size}B-lr{lr}-{date}-hidden_layer(-?\\d+)-seed(\\d+)_{target_concept_config_name}_initvecwith(.*)"
    dirname_pattern2 = f"gemma-3-{model_size}B-lr{lr}-{date}-seed(\\d+)_{target_concept_config_name}_initvecwith(.*)"
    initVecType_to_seed_to_maxacc = defaultdict(dict)
    initVecType_to_seed_to_epoch_at_maxacc = defaultdict(dict)
    for dirname in os.listdir(result_dir):

        if re.match(dirname_pattern1, dirname):
            match_groups = re.search(dirname_pattern1, dirname)
            layer_idx = int(match_groups.group(1))
            seed = int(match_groups.group(2))
            initVecType = f"{match_groups.group(3)}_layer{layer_idx}"
        elif re.match(dirname_pattern2, dirname):
            match_groups = re.search(dirname_pattern2, dirname)
            print(match_groups)
            seed = int(match_groups.group(1))
            initVecType = match_groups.group(2)
        else:
            if date in dirname:
                # print(dirname)
                pass
            continue  # ディレクトリ名がどちらのパターンにもマッチしない場合はスキップ

        # print(f"Processing directory: {dirname}, initVecType: {initVecType}, seed: {seed}")
        
        if not os.path.exists(os.path.join(result_dir, dirname, 'logit_score_summary.json')):
            # print(f"Warning: logit_score_summary.json not found in {dirname}. Skipping.")
            continue
        with open(os.path.join(result_dir, dirname, 'logit_score_summary.json'), "r") as f:
            concept_to_epoch_to_scores = json.load(f)

        # 各conceptについて、回したepochs中の最高到達accuracyとそのepochを抽出
        max_accs = []
        epochs_at_maxacc = []
        for epoch_to_scores in concept_to_epoch_to_scores.values():
            max_accuracy = 0
            max_epoch_at_maxacc = 0
            for epoch, scores in epoch_to_scores.items():
                # print(f"Epoch: {epoch}, Accuracy: {scores['accuracy']}")
                if scores['accuracy'] > max_accuracy:
                    max_accuracy = scores['accuracy']
                    max_epoch_at_maxacc = epoch
            max_accs.append(max_accuracy)
            epochs_at_maxacc.append(max_epoch_at_maxacc)
        # print(f"Max Accuracies: {max_accs}")
        # print(f"Epochs at Max Accuracies: {epochs_at_maxacc}")
        initVecType_to_seed_to_maxacc[initVecType][seed] = max_accs
        initVecType_to_seed_to_epoch_at_maxacc[initVecType][seed] = epochs_at_maxacc
    return initVecType_to_seed_to_maxacc, initVecType_to_seed_to_epoch_at_maxacc

# %% [markdown]
# ## 12B

# %%
date = '20260423'
model_size = '12'
lr = 0.003

target_concept_config_name = 'target_concepts_mini_13.json'

# %%
initVecType_to_seed_to_maxacc, initVecType_to_seed_to_epoch_at_maxacc = load_file_and_extract_max_accs(
    date, lr, target_concept_config_name, model_size, result_dir
)

seeds = set([seed for seed_to_maxacc in initVecType_to_seed_to_maxacc.values() for seed in seed_to_maxacc.keys()])
initVecType_lst = sorted(list(initVecType_to_seed_to_maxacc.keys()))

for seed in seeds:
    print(f"Seed: {seed}")
    for initVecType in initVecType_lst:
        max_accs = initVecType_to_seed_to_maxacc[initVecType].get(seed, None)
        if max_accs:
            mean_max_acc = np.mean(max_accs)
            std_max_acc = np.std(max_accs)
            print(f"\tInitVecType: {initVecType:15}, Seed: {seed}, Mean Max Accuracy: {mean_max_acc:.4f}, Std: {std_max_acc:.4f}")

print('\n' + '-' * 100 + '\n')

for seed in seeds:
    print(f"Seed: {seed}")
    for initVecType in initVecType_lst:
        epochs_at_maxacc = initVecType_to_seed_to_epoch_at_maxacc[initVecType].get(seed, None)

        if epochs_at_maxacc:
            mean_epoch_at_maxacc = np.mean([int(e) for e in epochs_at_maxacc])
            std_epoch_at_maxacc = np.std([int(e) for e in epochs_at_maxacc])
        print(f"\tInitVecType: {initVecType:15}, Seed: {seed}, Mean Epoch number at Max Accuracy: {mean_epoch_at_maxacc:.2f}, Std: {std_epoch_at_maxacc:.2f}")
# Out:
# Seed: 0
# 	InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 0, Mean Max Accuracy: 0.7496, Std: 0.1168
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 0, Mean Max Accuracy: 0.7620, Std: 0.1453
# 	InitVecType: otherCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 0, Mean Max Accuracy: 0.7485, Std: 0.1247
# Seed: 1
# 	InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 1, Mean Max Accuracy: 0.7447, Std: 0.1208
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 1, Mean Max Accuracy: 0.7565, Std: 0.1459
# 	InitVecType: otherCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 1, Mean Max Accuracy: 0.7727, Std: 0.1211
# Seed: 2
# 	InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 2, Mean Max Accuracy: 0.7811, Std: 0.1372
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 2, Mean Max Accuracy: 0.7516, Std: 0.1353
# 	InitVecType: otherCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 2, Mean Max Accuracy: 0.7494, Std: 0.1347
# Seed: 3
# 	InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 3, Mean Max Accuracy: 0.7467, Std: 0.1417
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 3, Mean Max Accuracy: 0.7657, Std: 0.1051
# 	InitVecType: otherCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 3, Mean Max Accuracy: 0.7413, Std: 0.1334
# Seed: 4
# 	InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 4, Mean Max Accuracy: 0.7367, Std: 0.1235
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 4, Mean Max Accuracy: 0.7197, Std: 0.1440
# 	InitVecType: otherCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 4, Mean Max Accuracy: 0.7694, Std: 0.1553
# Seed: 5
# 	InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 5, Mean Max Accuracy: 0.7415, Std: 0.1098
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 5, Mean Max Accuracy: 0.7289, Std: 0.1281
# 	InitVecType: otherCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 5, Mean Max Accuracy: 0.7241, Std: 0.1435
# Seed: 6
# 	InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 6, Mean Max Accuracy: 0.7400, Std: 0.1328
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 6, Mean Max Accuracy: 0.7402, Std: 0.1216
# 	InitVecType: otherCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 6, Mean Max Accuracy: 0.7395, Std: 0.1287
# Seed: 7
# 	InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 7, Mean Max Accuracy: 0.7540, Std: 0.1185
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 7, Mean Max Accuracy: 0.7205, Std: 0.1135
# 	InitVecType: otherCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 7, Mean Max Accuracy: 0.7381, Std: 0.1170
# Seed: 8
# 	InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 8, Mean Max Accuracy: 0.7184, Std: 0.1472
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 8, Mean Max Accuracy: 0.7567, Std: 0.1369
# 	InitVecType: otherCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 8, Mean Max Accuracy: 0.7477, Std: 0.1158
# Seed: 9
# 	InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 9, Mean Max Accuracy: 0.7337, Std: 0.1369
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 9, Mean Max Accuracy: 0.7728, Std: 0.1435
# 	InitVecType: otherCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 9, Mean Max Accuracy: 0.6944, Std: 0.1383
#
# ----------------------------------------------------------------------------------------------------
#
# Seed: 0
# 	InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 0, Mean Epoch number at Max Accuracy: 3.15, Std: 1.63
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 0, Mean Epoch number at Max Accuracy: 3.23, Std: 1.55
# 	InitVecType: otherCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 0, Mean Epoch number at Max Accuracy: 3.54, Std: 1.28
# Seed: 1
# 	InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 1, Mean Epoch number at Max Accuracy: 2.19, Std: 1.27
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 1, Mean Epoch number at Max Accuracy: 2.50, Std: 1.37
# 	InitVecType: otherCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 1, Mean Epoch number at Max Accuracy: 2.77, Std: 1.09
# Seed: 2
# 	InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 2, Mean Epoch number at Max Accuracy: 3.04, Std: 1.60
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 2, Mean Epoch number at Max Accuracy: 3.08, Std: 1.36
# 	InitVecType: otherCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 2, Mean Epoch number at Max Accuracy: 3.42, Std: 1.34
# Seed: 3
# 	InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 3, Mean Epoch number at Max Accuracy: 3.35, Std: 1.39
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 3, Mean Epoch number at Max Accuracy: 3.31, Std: 1.35
# 	InitVecType: otherCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 3, Mean Epoch number at Max Accuracy: 2.65, Std: 1.27
# Seed: 4
# 	InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 4, Mean Epoch number at Max Accuracy: 2.96, Std: 1.32
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 4, Mean Epoch number at Max Accuracy: 2.50, Std: 1.34
# 	InitVecType: otherCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 4, Mean Epoch number at Max Accuracy: 3.15, Std: 1.23
# Seed: 5
# 	InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 5, Mean Epoch number at Max Accuracy: 3.35, Std: 1.24
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 5, Mean Epoch number at Max Accuracy: 3.00, Std: 1.14
# 	InitVecType: otherCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 5, Mean Epoch number at Max Accuracy: 3.27, Std: 1.43
# Seed: 6
# 	InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 6, Mean Epoch number at Max Accuracy: 3.04, Std: 1.58
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 6, Mean Epoch number at Max Accuracy: 2.92, Std: 1.38
# 	InitVecType: otherCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 6, Mean Epoch number at Max Accuracy: 2.92, Std: 1.36
# Seed: 7
# 	InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 7, Mean Epoch number at Max Accuracy: 3.35, Std: 1.17
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 7, Mean Epoch number at Max Accuracy: 3.35, Std: 1.27
# 	InitVecType: otherCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 7, Mean Epoch number at Max Accuracy: 3.54, Std: 1.60
# Seed: 8
# 	InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 8, Mean Epoch number at Max Accuracy: 2.58, Std: 1.39
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 8, Mean Epoch number at Max Accuracy: 3.23, Std: 1.48
# 	InitVecType: otherCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 8, Mean Epoch number at Max Accuracy: 3.27, Std: 1.58
# Seed: 9
# 	InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 9, Mean Epoch number at Max Accuracy: 2.54, Std: 1.42
# 	InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 9, Mean Epoch number at Max Accuracy: 2.77, Std: 1.37
# 	InitVecType: otherCatCent_by_WikiSummaryRepeatHSMixed_layer12, Seed: 9, Mean Epoch number at Max Accuracy: 2.88, Std: 1.12

# %% [markdown]
# ## epoch4固定でaccuracyを計算する

# %%
sys.path.append(project_root)

from utils.gemma_train_and_test_utils import calculate_metrics

def get_concept_to_epoch_score(concept_result_dir, epoch):
    concept_to_results = {}
    for dirname in os.listdir(concept_result_dir):
        if dirname.endswith(".json"):
            continue
        concept = dirname

        # このconceptに対するepochの結果を読み込む
        logit_score_path = os.path.join(concept_result_dir, dirname, f"logit-scored_epoch{epoch}.json")
        
        if not os.path.exists(logit_score_path):
            # raise FileNotFoundError(f"Logit score file not found: {logit_score_path}")
            # print(f"Logit score file not found: {logit_score_path}. Skipping this concept.")
            continue
            
        with open(logit_score_path, 'r') as f:
            results = json.load(f)
        y_true_lst = [res['label'] for res in results]
        y_pred_lst = [res['pred'] for res in results]

        # score計算
        metrics = calculate_metrics(y_pred_lst, y_true_lst)

        concept_to_results[concept] = metrics

        # print(f"  Epoch {epoch}: Accuracy: {metrics['accuracy']:.4f}, Precision: {metrics['precision']:.4f}, Recall: {metrics['recall']:.4f}, F1: {metrics['F1']:.4f}")
    
    return concept_to_results





def load_file_and_calc_epoch_accs(date, epoch, lr, target_concept_config_name, model_size, result_dir, print_flag=False):
    """各initVecTypeとseedに対して、回したepochs中の最高到達accuracyを抽出する関数"""

    target_concept_config_name = target_concept_config_name.replace('.json', '')
    dirname_pattern1 = f"gemma-3-{model_size}B-lr{lr}-{date}-hidden_layer(-?\\d+)-seed(\\d+)_{target_concept_config_name}_initvecwith(.*)"
    dirname_pattern2 = f"gemma-3-{model_size}B-lr{lr}-{date}-seed(\\d+)_{target_concept_config_name}_initvecwith(.*)"

    initvectype_to_seed_to_acc = defaultdict(dict)
    for dirname in os.listdir(result_dir):

        if re.match(dirname_pattern1, dirname):
            match_groups = re.search(dirname_pattern1, dirname)
            layer_idx = int(match_groups.group(1))
            seed = int(match_groups.group(2))
            initVecType = f"{match_groups.group(3)}_layer{layer_idx}"
        elif re.match(dirname_pattern2, dirname):
            match_groups = re.search(dirname_pattern2, dirname)
            print(match_groups)
            seed = int(match_groups.group(1))
            initVecType = match_groups.group(2)
        else:
            if date in dirname:
                pass
            continue  # ディレクトリ名がどちらのパターンにもマッチしない場合はスキップ

        concept_to_results = get_concept_to_epoch_score(os.path.join(result_dir, dirname), epoch)
        if len(concept_to_results) == 0:
            # print(f"No valid concepts with logit score files found for directory: {dirname}. Skipping.")
            continue
        sum_acc = 0
        for concept, score in concept_to_results.items():
            acc = score['accuracy']
            sum_acc += acc

        avg_acc = sum_acc / len(concept_to_results)
        initvectype_to_seed_to_acc[initVecType][seed] = avg_acc
        if print_flag:
            print(f"InitVecType: {initVecType}, Seed: {seed}, Average Accuracy at Epoch {epoch}: {avg_acc:.4f}")

    return initvectype_to_seed_to_acc

# %%
layer = 12
seed_num = 10

for epoch in range(1, 6):   # train時にrange(maxEpoch)としていたせいでmaxEpoch=5でもepoch4までしか回していなかった。さらにmaxEpoch時点のモデルとして最終ループepoch4の結果が保存されてしまっていた。2026/04/20の結果まで。なので1引いて4epochまでの結果のみ読み込む
    print(f"Epoch: {epoch}")


    date = '20260423'
    initvectype_to_seed_to_acc = load_file_and_calc_epoch_accs(date, epoch, lr=lr, 
                                                            target_concept_config_name=target_concept_config_name, 
                                                            model_size=model_size, 
                                                            result_dir=result_dir,
                                                            print_flag=False)


    # ** Cat **
    initVecType = f'CatCent_by_WikiSummaryRepeatHSMixed_layer{layer}'
    print(f"InitVecType: {initVecType}")
    acc_lst = []
    for seed in range(seed_num):
        seed_to_acc = initvectype_to_seed_to_acc.get(initVecType, {})
        acc = seed_to_acc.get(seed, None)
        if acc is not None:
            acc_lst.append(acc)
            # print(f"InitVecType: {initVecType}, Seed: {seed}, Average Accuracy at Epoch {epoch}: {acc:.4f}")
        else:
            # print(f"  InitVecType: {initVecType}, No data for Seed {seed}")
            pass
    print(acc_lst)
        
    # mean ± std
    mean = np.mean(acc_lst)
    std = np.std(acc_lst)
    print(f"accuracy at epoch {epoch}: {mean:.4f} ± {std:.4f}")
    print()
    cat_acc_lst = acc_lst


    # ** nearCat **
    initVecType = f'nearCatCent_by_WikiSummaryRepeatHSMixed_layer{layer}'
    print(f"InitVecType: {initVecType}")
    acc_lst = []
    for seed in range(seed_num): 
        seed_to_acc = initvectype_to_seed_to_acc.get(initVecType, {})
        acc = seed_to_acc.get(seed, None)
        if acc is not None:
            acc_lst.append(acc)
            # print(f"InitVecType: {initVecType}, Seed: {seed}, Average Accuracy at Epoch {epoch}: {acc:.4f}")
        else:
            # print(f"  InitVecType: {initVecType}, No data for Seed {seed}")
            pass
    print(acc_lst)
        
    # mean ± std
    mean = np.mean(acc_lst)
    std = np.std(acc_lst)
    print(f"accuracy at epoch {epoch}: {mean:.4f} ± {std:.4f}")
    print()
    nearcat_acc_lst = acc_lst



    # ** otherCat **
    initVecType = f'otherCatCent_by_WikiSummaryRepeatHSMixed_layer{layer}'
    print(f"InitVecType: {initVecType}")
    acc_lst = []
    for seed in range(seed_num):
        seed_to_acc = initvectype_to_seed_to_acc.get(initVecType, {})
        acc = seed_to_acc.get(seed, None)
        if acc is not None:
            acc_lst.append(acc)
            # print(f"InitVecType: {initVecType}, Seed: {seed}, Average Accuracy at Epoch {epoch}: {acc:.4f}")
        else:
            # print(f"  InitVecType: {initVecType}, No data for Seed {seed}")
            pass
    print(acc_lst)
    
    # mean ± std
    mean = np.mean(acc_lst)
    std = np.std(acc_lst)
    print(f"accuracy at epoch {epoch}: {mean:.4f} ± {std:.4f}")
    print()
    othercat_acc_lst = acc_lst

    



    date = '20260418'
    initvectype_to_seed_to_acc = load_file_and_calc_epoch_accs(date, epoch, lr=lr, 
                                                            target_concept_config_name=target_concept_config_name, 
                                                            model_size=model_size, 
                                                            result_dir=result_dir,
                                                            print_flag=False)
    # ** norm_rand_vocab **
    initVecType = f'norm_rand_vocab_layer{layer}'
    print(f"InitVecType: {initVecType}")
    acc_lst = []
    for seed in range(seed_num):
        seed_to_acc = initvectype_to_seed_to_acc.get(initVecType, {})
        acc = seed_to_acc.get(seed, None)
        if acc is not None:
            acc_lst.append(acc)
            # print(f"InitVecType: {initVecType}, Seed: {seed}, Average Accuracy at Epoch {epoch}: {acc:.4f}")
        else:
            print(f"  InitVecType: {initVecType}, No data for Seed {seed}")
    print(acc_lst)

    # mean ± std
    mean = np.mean(acc_lst)
    std = np.std(acc_lst)
    print(f"accuracy at epoch {epoch}: {mean:.4f} ± {std:.4f}")
    print()
    norm_rand_vocab_acc_lst = acc_lst



    # ** zero **
    initVecType = f'zero_layer{layer}'
    print(f"InitVecType: {initVecType}")
    acc_lst = []
    for seed in range(seed_num):
        seed_to_acc = initvectype_to_seed_to_acc.get(initVecType, {})
        acc = seed_to_acc.get(seed, None)
        if acc is not None:
            acc_lst.append(acc)
            # print(f"InitVecType: {initVecType}, Seed: {seed}, Average Accuracy at Epoch {epoch}: {acc:.4f}")
        else:
            print(f"  InitVecType: {initVecType}, No data for Seed {seed}")
    print(acc_lst)

    # mean ± std
    mean = np.mean(acc_lst)
    std = np.std(acc_lst)
    print(f"accuracy at epoch {epoch}: {mean:.4f} ± {std:.4f}")
    zero_acc_lst = acc_lst

    print('\n==============================\n==============================\n')
# Out:
# Epoch: 1
# InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12
# [0.6378419390233057, 0.6673547243053559, 0.6552580890697646, 0.5957782000596082, 0.6280284890237909, 0.5969879165693873, 0.6258515632930624, 0.623973815742481, 0.6141812837994972, 0.6360142373147084]
# accuracy at epoch 1: 0.6281 ± 0.0216
#
# InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12
# [0.6193067104976129, 0.6397094731565277, 0.6355212834976739, 0.5958875525636456, 0.6108715357161967, 0.6158449461364198, 0.6509010363807476, 0.6008354002198193, 0.6140420962741856, 0.6543327093142346]
# accuracy at epoch 1: 0.6237 ± 0.0193
#
# InitVecType: otherCatCent_by_WikiSummaryRepeatHSMixed_layer12
# [0.40228898422638487, 0.6508220545259421, 0.6018942370227325, 0.6053191644165846, 0.6526526484535953, 0.6050845456936671, 0.628597868984435, 0.5757595502953442, 0.6455484033785435, 0.5430532828651224]
# accuracy at epoch 1: 0.5911 ± 0.0710
#
# InitVecType: norm_rand_vocab_layer12
# [0.5877783877011918, 0.6125625581591442, 0.6243171282314388, 0.5875983165489136, 0.6394275312337115, 0.5736421943034672, 0.643990115889439, 0.5441013108862109, 0.636321388313437, 0.5877425588623955]
# accuracy at epoch 1: 0.6037 ± 0.0311
#
# InitVecType: zero_layer12
# [0.5807310320347437, 0.5247740687947468, 0.5500913405385442, 0.5873729160701612, 0.5177735848601164, 0.5488742213298244, 0.5277451926465028, 0.570430436880718, 0.5608318921098954, 0.5359881036031047]
# accuracy at epoch 1: 0.5505 ± 0.0229
#
# ==============================
# ==============================
#
# Epoch: 2
# InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12
# [0.647859143431756, 0.6637841011129293, 0.6877938356922393, 0.6496716287663369, 0.6441848905685114, 0.6529581617304648, 0.6451356266512774, 0.6403585204100024, 0.6543726551379634, 0.6530860012594025]
# accuracy at epoch 2: 0.6539 ± 0.0129
#
# InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12
# [0.6745845838531005, 0.6719386750205076, 0.641958229107038, 0.6540098868771806, 0.6392095703978973, 0.6532179364755526, 0.6657148484185189, 0.6009698471399861, 0.6405859840264985, 0.6672832022972888]
# accuracy at epoch 2: 0.6509 ± 0.0208
#
# InitVecType: otherCatCent_by_WikiSummaryRepeatHSMixed_layer12
# [0.6710887292414125, 0.7165199094151029, 0.6236261399208196, 0.6744474142652938, 0.696206267806219, 0.6175586706115789, 0.6463407113535448, 0.6185594404657705, 0.647440924280731, 0.607353927430814]
# accuracy at epoch 2: 0.6519 ± 0.0348
#
# InitVecType: norm_rand_vocab_layer12
# [0.6522056324870152, 0.6176438472469286, 0.6591828253561439, 0.6301544839483104, 0.6556122799857147, 0.6120959458699112, 0.6620245960055894, 0.6125848470979816, 0.6129906212304483, 0.6274452281321072]
# accuracy at epoch 2: 0.6342 ± 0.0198
#
# InitVecType: zero_layer12
# [0.6065666112358944, 0.5601345132392684, 0.5608221209487481, 0.6037289219549682, 0.5607678639481555, 0.5811184516291097, 0.5521206651531387, 0.6210561343564038, 0.5999162889921719, 0.5777346967005326]
# accuracy at epoch 2: 0.5824 ± 0.0228
#
# ==============================
# ==============================
#
# Epoch: 3
# InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12
# [0.6613492463569836, 0.6563219941452867, 0.6859283939173972, 0.6584933107234616, 0.675385649316299, 0.682726452254674, 0.6692577862660161, 0.6756344605256661, 0.6463544590135346, 0.6425510491194638]
# accuracy at epoch 3: 0.6654 ± 0.0140
#
# InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12
# [0.706571711707903, 0.6934342764866854, 0.674392332353498, 0.6751216888036029, 0.6672499562171103, 0.6801835231156088, 0.6597837352086, 0.6368580907300766, 0.6714805784943831, 0.6993040130691343]
# accuracy at epoch 3: 0.6764 ± 0.0192
#
# InitVecType: otherCatCent_by_WikiSummaryRepeatHSMixed_layer12
# [0.6765253407807209, 0.7071810853861697, 0.6791684552579765, 0.6870951646260735, 0.6777924316064142, 0.6290189693284398, 0.6510649413554573, 0.6583544403691063, 0.658446231519185, 0.6322553272052686]
# accuracy at epoch 3: 0.6657 ± 0.0233
#
# InitVecType: norm_rand_vocab_layer12
# [0.6449129429799645, 0.6275860296354211, 0.6711807907057358, 0.6520748464424181, 0.6841620760332568, 0.6564135137093452, 0.6668775238266915, 0.6220289975576871, 0.6560656070503206, 0.6635820926776923]
# accuracy at epoch 3: 0.6545 ± 0.0181
#
# InitVecType: zero_layer12
# [0.6151410654908731, 0.5503915823483265, 0.6329937208405938, 0.6340890065205069, 0.5773835756599044, 0.6172008415022963, 0.5629183432148845, 0.6448175970297216, 0.6048946670956267, 0.5941766014276153]
# accuracy at epoch 3: 0.6034 ± 0.0301
#
# ==============================
# ==============================
#
# Epoch: 4
# InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12
# [0.6989224467634874, 0.6625320742812911, 0.6985459366577639, 0.6718485268143001, 0.6826301188117954, 0.6820323721729266, 0.653450786686165, 0.696440480246122, 0.6508749624386263, 0.6643846080978268]
# accuracy at epoch 4: 0.6762 ± 0.0173
#
# InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12
# [0.6973683775436121, 0.6773412160036967, 0.6862332797811065, 0.7224083119677179, 0.6718982894736218, 0.6671500452622335, 0.6871932061753065, 0.6711770108487253, 0.7083724062092615, 0.7021993172094382]
# accuracy at epoch 4: 0.6891 ± 0.0172
#
# InitVecType: otherCatCent_by_WikiSummaryRepeatHSMixed_layer12
# [0.6838275347205071, 0.6981919133140402, 0.690118954888789, 0.660358963233958, 0.695367064102345, 0.6813280350040795, 0.6982390707446403, 0.6589830543033963, 0.6759169492411117, 0.6411486900733038]
# accuracy at epoch 4: 0.6783 ± 0.0183
#
# InitVecType: norm_rand_vocab_layer12
# [0.6449129429799645, 0.6275860296354211, 0.6711807907057358, 0.6520748464424181, 0.6841620760332568, 0.6564135137093452, 0.6668775238266915, 0.6220289975576871, 0.6560656070503206, 0.6635820926776923]
# accuracy at epoch 4: 0.6545 ± 0.0181
#
# InitVecType: zero_layer12
# [0.6151410654908731, 0.5503915823483265, 0.6329937208405938, 0.6340890065205069, 0.5773835756599044, 0.6172008415022963, 0.5629183432148845, 0.6448175970297216, 0.6048946670956267, 0.5941766014276153]
# accuracy at epoch 4: 0.6034 ± 0.0301
#
# ==============================
# ==============================
#
# Epoch: 5
# InitVecType: CatCent_by_WikiSummaryRepeatHSMixed_layer12
# [0.6873733257353455, 0.6619842913322075, 0.7070230841823923, 0.6832901380783988, 0.6764957064510886, 0.6877782771350318, 0.6926282502648907, 0.6873926047398565, 0.6453723483653098, 0.6601916520180138]
# accuracy at epoch 5: 0.6790 ± 0.0173
#
# InitVecType: nearCatCent_by_WikiSummaryRepeatHSMixed_layer12
# [0.728625301651927, 0.6952803460209558, 0.6947399605642677, 0.7185212595636359, 0.6463243979862111, 0.6515845868970573, 0.6909746298677779, 0.665035545569904, 0.7100534644988036, 0.7076488369221502]
# accuracy at epoch 5: 0.6909 ± 0.0266
#
# InitVecType: otherCatCent_by_WikiSummaryRepeatHSMixed_layer12
# [0.6924886590389144, 0.6997620922466526, 0.6873803948878959, 0.649864782085247, 0.7190700206487415, 0.6669979255035395, 0.685282751015868, 0.6810831880771803, 0.7012019733068815, 0.6156148577179081]
# accuracy at epoch 5: 0.6799 ± 0.0280
#
# InitVecType: norm_rand_vocab_layer12
#   InitVecType: norm_rand_vocab_layer12, No data for Seed 0
#   InitVecType: norm_rand_vocab_layer12, No data for Seed 1
#   InitVecType: norm_rand_vocab_layer12, No data for Seed 2
#   InitVecType: norm_rand_vocab_layer12, No data for Seed 3
#   InitVecType: norm_rand_vocab_layer12, No data for Seed 4
#   InitVecType: norm_rand_vocab_layer12, No data for Seed 5
#   InitVecType: norm_rand_vocab_layer12, No data for Seed 6
#   InitVecType: norm_rand_vocab_layer12, No data for Seed 7
#   InitVecType: norm_rand_vocab_layer12, No data for Seed 8
#   InitVecType: norm_rand_vocab_layer12, No data for Seed 9
# []
# accuracy at epoch 5: nan ± nan
#
# InitVecType: zero_layer12
#   InitVecType: zero_layer12, No data for Seed 0
#   InitVecType: zero_layer12, No data for Seed 1
#   InitVecType: zero_layer12, No data for Seed 2
#   InitVecType: zero_layer12, No data for Seed 3
#   InitVecType: zero_layer12, No data for Seed 4
#   InitVecType: zero_layer12, No data for Seed 5
#   InitVecType: zero_layer12, No data for Seed 6
#   InitVecType: zero_layer12, No data for Seed 7
#   InitVecType: zero_layer12, No data for Seed 8
#   InitVecType: zero_layer12, No data for Seed 9
# []
# accuracy at epoch 5: nan ± nan
#
# ==============================
# ==============================
# /home/toko/project/EmbedNewConcept-20260305/.venv/lib/python3.12/site-packages/numpy/_core/fromnumeric.py:3824: RuntimeWarning: Mean of empty slice
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/toko/project/EmbedNewConcept-20260305/.venv/lib/python3.12/site-packages/numpy/_core/_methods.py:142: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/toko/project/EmbedNewConcept-20260305/.venv/lib/python3.12/site-packages/numpy/_core/_methods.py:219: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/toko/project/EmbedNewConcept-20260305/.venv/lib/python3.12/site-packages/numpy/_core/_methods.py:178: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /home/toko/project/EmbedNewConcept-20260305/.venv/lib/python3.12/site-packages/numpy/_core/_methods.py:211: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
